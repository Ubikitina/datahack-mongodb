# %% [markdown]
# # Práctica NoSQL
#
# <span style="color:red">**_(Noota: Revisar la ortografía en todo el documento.)_**</span>
#
#
# ## Objetivo
#
# El propósito de esta práctica es consolidar y demostrar los conocimientos adquiridos en el modelado y gestión de datos NoSQL.
#
# Con este fin, para la implementación de esta práctica, he seleccionado el conjunto de datos de la **Calidad del Aire de la ciudad de Madrid** y he preparado un caso de uso y su correspondiente implementación utilizando MongoDB como sistema de base de datos orientado a documentos.
#
#
#
# ## Caso de uso
#
# ### Descripción de la fuente de datos
#
# El conjunto de datos seleccionado proporciona información sobre la calidad del aire en la ciudad de Madrid. Contiene una serie temporal de mediciones diarias y por horas de diferentes contaminantes, como el dióxido de nitrógeno (NO2), recopiladas en diversas estaciones de medición.
#
# Cada registro de medición incluye la fecha en la que se realizó, la estación de medición correspondiente, la magnitud medida, y las mediciones realizadas por horas para esa magnitud en particular.
#
# Además, se proporciona información detallada sobre cada estación de medición, que incluye su código único, fecha de alta, tipo de estación, magnitudes que mide, y detalles de su ubicación, como la altitud, coordenadas geográficas, y dirección.
#
#
#
# ### Descripción del caso de uso
# **Caso de uso**: Análisis de la evolución temporal de NO2 en las estaciones de medición de la calidad del aire de Madrid durante 2023.
#
# El propósito de este análisis es examinar la evolución temporal del dióxido de nitrógeno (NO2) en las estaciones de medición de Madrid durante el año 2023. Este enfoque permitirá realizar una comparación de los niveles de NO2 entre los diferentes periodos de tiempo (por ejemplo, meses) y comprender cómo varía este parámetro a lo largo del tiempo.
#
# La selección de NO2 como variable de interés se justifica por su relevancia en varios aspectos:
#
# 1. **Impacto en la salud**: El NO2 puede tener efectos adversos en el sistema respiratorio humano, como la irritación pulmonar, el agravamiento del asma y el aumento del riesgo de enfermedades respiratorias crónicas.
#
# 2. **Papel como precursor del Ozono (O3)**: El NO2 contribuye a la formación de ozono troposférico, un contaminante secundario que puede tener efectos perjudiciales en la salud humana y el medio ambiente.
#
# 3. **Relación con fuentes de emisión específicas**: Su origen es principalmente antropogénico, lo que hace un indicador útil de la contaminación producida por actividades humanas, como la combustión de combustibles fósiles (gas natural, petróleo, carbón, etc.) mediante vehículos motorizados, plantas de energía u otros medios.
#
# Se ha comprobado que el dataset disponible contiene una cantidad significativa de estaciones y mediciones de este contaminante, lo que nos proporciona una base de datos adecuada para llevar a cabo nuestro análisis.
#
# Como Ingeniera de Datos, seleccionaré el mejor sistema de base de datos para este caso de uso, así como prepararé el modelado de datos para optimizar la consultas necesarias para hacer analítica de datos (por ejemplo, medias aritmética mensuales) del dióxido de nitrógeno (NO2) en las estaciones, para que después, los Analistas de Datos puedan crear informes sobre los datos extraidos y sacar conclusiones.
#
#
#
# ### Análsis de los sistemas de bases de datos
#
# En esta sección, evaluaremos la selección del sistema de bases de datos más adecuado para nuestro caso de uso. Para ello, primero definiremos los requisitos específicos que guiarán nuestra elección y, a continuación, analizaremos los diferentes sistemas de bases de datos.
#
# **Requerimientos:**
#
# 1. **Operaciones Analíticas**: El enfoque principal de nuestro caso de uso es realizar operaciones analíticas sobre la información almacenada. Priorizamos la capacidad del sistema de bases de datos para soportar operaciones analíticas complejas de manera eficiente.
#
# 2. **No necesitamos alto rendimiento, ya que la disponibilidad de la información es en diferido**: No necesitamos acceso inmediato a los resultados del análisis. Las consultas pueden tardar segundos o minutos en procesarse sin afectar la utilidad de nuestro estudio.
#
# 3. **Gestión eficiente de Series Temporales (_Time Series_)**: Debido a la naturaleza temporal de nuestros datos, es crucial que el sistema de bases de datos pueda gestionar grandes volúmenes de mediciones temporales de manera eficiente.
#
# 4. **Consistencia de Datos Científicos**: Dada la naturaleza científica de nuestros datos, la consistencia es fundamental. Los resultados podrían utilizarse en un futuro para la toma de decisiones basadas en umbrales predefinidos.
#
# 5. **Necesidad de particionado**: La gran cantidad de datos generados por los sensores requiere la capacidad de particionar los datos para una gestión más eficiente.
#
# 6. **Escalabilidad**: Dado el crecimiento rápido y constante de nuestros datos, la capacidad de escalar de forma eficiente es esencial para manejar volúmenes de datos en constante aumento.
#
# El listado de requisitos está diseñado específicamente para nuestro caso de uso principal. Si bien nuestros datos también podrían sugerir otros requisitos potenciales, como el manejo de índices geoespaciales para futuros análisis de áreas geográficas contaminadas, estos se considerarán como posibles necesidades adicionales durante la selección del sistema de bases de datos.
#
#
# A continuación, analizaremos los diferentes sistemas de bases de datos existentes y buscaremos el más apropiado para nuestro caso de uso.
#
# **Bases de datos relacionales**
#
# Una base de datos relacional (RDBMS) es un sistema de gestión de bases de datos que organiza los datos en tablas con relaciones definidas entre ellas. Utiliza un esquema rígido y sigue el estándar SQL para consultar y manipular los datos. Además, garantiza la consistencia e integridad de los datos mediante el cumplimiento del Teorema ACID y soporta transacciones.
#
#
# | Requerimiento            | Evaluación                                                                                                          |
# |--------------------------|---------------------------------------------------------------------------------------------------------------------|
# | Operaciones Analíticas   | Las bases de datos relacionales no fueron específicamente diseñadas para operaciones analíticas, aunque pueden manejarlas hasta cierto punto. Originalmente, fueron diseñadas para gestionar transacciones. Configurándolas de forma apropiada, podríamos obtener un rendimiento válido para nuestro caso de uso. |
# | Rendimiento              | Configurándolas de forma apropiada, podríamos obtener un rendimiento válido para nuestro caso de uso.                |
# | Gestión de Series Temporales | Las bases de datos relacionales no fueron diseñadas para la gestión de series temporales. Pueden gestionar series temporales utilizando tablas con registros de fecha y hora, y consultas SQL que incluyan funciones de fecha y hora. Sin embargo, no son la opción más eficiente para grandes volúmenes de datos temporales debido a la estructura de almacenamiento y las optimizaciones de índices. |
# | Consistencia de Datos    | Garantizan la consistencia de datos mediante el cumplimiento de ACID (Atomicidad, Consistencia, Aislamiento y Durabilidad). |
# | Particionado             | Admiten particionado de datos mediante la división de tablas en fragmentos lógicos o físicos. Sin embargo, puede requerir trabajo manual y configuración. |
# | Escalabilidad           | Las bases de datos relacionales pueden escalar verticalmente (aumentando los recursos en el servidor) y horizontalmente (distribuyendo datos en varios servidores), pero el escalado horizontal es complicado de implementar y gestionar. |
#
#
# Por lo tanto, concluimos que una base de datos relacional puede ser adecuada para ciertos aspectos del análisis de la calidad del aire, como la garantía de consistencia de datos y la disponibilidad diferida de la información, pero puede no ser la opción más eficiente ni escalable para la gestión de grandes volúmenes de datos temporales y operaciones analíticas complejas.
#
#
# **Clave/Valor (NoSQL)**
#
# Las bases de datos clave/valor son sistemas de almacenamiento de datos que no requieren un esquema asociado al valor almacenado, tratando el valor simplemente como un array de bytes. Estas bases de datos únicamente ofrecen operaciones básicas como añadir o eliminar un par clave/valor, así como obtener o modificar el valor asociado a una clave específica. Sin embargo, carecen de capacidades avanzadas como búsqueda sobre los valores almacenados, filtros, agrupaciones, agregaciones o joins entre datos. Su simplicidad las hace ideales para aplicaciones donde la estructura de datos es simple y la eficiencia en la recuperación de datos es prioritaria sobre la capacidad de análisis avanzado. Es para casos de usos donde queramos realizar muchas consultas.
#
# | Requerimiento           | Evaluación                                                                                                                                                                      |
# |-------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Operaciones Analíticas  | Las bases de datos clave/valor no son adecuadas para operaciones analíticas complejas, ya que carecen de capacidades como filtrado, agregación y agrupación.                       |
# | Rendimiento             | Devuelven resultados de las consultas en milisegundos. Pero en nuestro caso de uso no necesitamos esta rapidez.                                                                  |
# | Gestión de Series Temporales | Aunque las bases de datos clave/valor pueden almacenar datos temporales utilizando claves que representen marcas de tiempo, no son la opción más adecuada, especialmente en términos de consultas analíticas sobre ellas. |
# | Consistencia de Datos   | Los niveles de consistencia dependen de la implementación. Por lo general, replica las particiones por el cluster y prima la disponibilidad de los datos (no SPOF), por lo que consigue una consistencia eventual, que no sería suficiente para nuestro caso de uso. |
# | Particionado            | Pueden ofrecer capacidades de particionado para distribuir la carga de trabajo.                                                                                                 |
# | Escalabilidad           | Pueden escalar horizontalmente para manejar volúmenes crecientes de datos mediante la adición de más nodos al clúster.                                                          |
#
# Para nuestro caso de uso, las bases de datos clave/valor no son adecuadas. Aunque ofrecen eficiencia en la recuperación de datos simples, carecen de capacidades para operaciones analíticas complejas, gestión de series temporales y garantía de consistencia de datos científicos, fundamentales en este caso.
#
#
#
# **Familias de Columnas (NoSQL)**
#
# Las bases de datos de Familias de Columnas se caracterizan por su enfoque en consultas específicas, donde se optimiza para un alto rendimiento de lectura. Para lograr esto, desnormalizan y redundan la información según las necesidades de consulta, como ordenación y agrupación. Esto implica conocer las consultas antes del modelado y persistir la información ya agrupada para evitar penalizaciones en el rendimiento. Estas bases de datos no soportan Joins, lo que penalizaría el rendimiento y la escalabilidad. Se adaptan bien a entornos donde las consultas son conocidas de antemano y se prioriza la eficiencia en la lectura sobre la complejidad del análisis. Un ejemplo de este tipo de bases de datos es Cassandra.
#
# | Requerimiento           | Evaluación                                                                                                                                                                      |
# |-------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Operaciones Analíticas  | Son adecuadas para realizar operaciones analíticas, siempre y cuando se diseñen para dichas operaciones, conociendo las consultas de antemano y preparando los datos para responderlas. No soportan funciones de agrupación, pero pueden persistir información ya agrupada valiéndonos del diseño de la arquitectura.            |
# | Rendimiento             | Rapidez en consultas de lectura. Sin embargo, esta rapidez no es necesaria en nuestro caso de uso.                                                                                                                                          |
# | Gestión de Series Temporales | Pueden gestionar series temporales al ordenar y repartir los datos según las necesidades de consulta.                                                                                                                                    |
# | Consistencia de Datos   | Por lo general, están más orientados a la disponibilidad de la información, más que a la consistencia (ejemplo: Cassandra). Pero dependiendo de cómo se implemente y administre la arquitectura, se puede implementar la consistencia, prestando atención al diseño y la configuración.                           |
# | Particionado            | Ofrecen capacidades de particionado para distribuir la carga de trabajo y manejar grandes volúmenes de datos. Se debe considerar el diseño del particionado teniendo en cuenta las consultas que queramos hacer.                                |
# | Escalabilidad           | Pueden escalar horizontalmente para manejar volúmenes crecientes de datos mediante la adición de más nodos al clúster. Se debe considerar la distribución de datos durante el escalado, para garantizar el rendimiento.                           |
#
# Tras la investigación, he concluido que una base de datos de columnas podría ser una solución para nuestro caso de uso, especialmente considerando su frecuente utilización en el ámbito del Internet de las Cosas (IoT) y en el análisis de series temporales. Estas bases de datos resultan particularmente eficaces cuando se requiere analizar o agregar solo un subconjunto de atributos. No obstante, para nuestro caso de uso, sería imprescindible abordar la implementación de la consistencia de datos, además de definir previamente las consultas que necesitaríamos realizar. Debido a estos dos motivos, y dado que este tipo de base de datos no ha sido abordado en el curso, descartamos su consideración.
#
#
#
# **Documentos (NoSQL)**
#
# Las bases de datos de documentos representan una estructura de almacenamiento donde cada documento constituye la unidad fundamental. Estos documentos organizan la información en una estructura jerárquica tipo árbol, y contienen un esquema flexible, permitiendo cambios. Un aspecto destacado es que los gestores de documentos indexan automáticamente todos los valores al insertar un documento, facilitando búsquedas eficientes. Cada documento se asocia con una clave única para su posterior recuperación. No admiten operaciones de join entre colecciones, pero gracias a la posibilidad de incluir documentos y arrays dentro de otros documentos, se reduce la necesidad de tales operaciones. Tanto Elastic como MongoDB son ejemplos de esta categoría.
#
#
# | Requerimiento          | Evaluación                                                                                                                                                                                      |
# |------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Operaciones Analíticas | Admiten operaciones analíticas, como agregaciones, filtrado y análisis de datos. MongoDB y Elastic permiten realizar operaciones de agregación y búsquedas agregadas.                        |
# | Rendimiento            | El rendimiento en la recuperación de datos puede no ser tan eficiente como en otros tipos de bases de datos (clave/valor). Sin embargo, el tiempo de respuesta no es un requerimiento crítico para nuestro caso de uso. |
# | Gestión de Series Temporales | Pueden gestionar series temporales mediante la inclusión de marcas de tiempo en los documentos. Sin embargo, si se requieren funciones avanzadas de series temporales, como interpolación, suavizado o análisis estadístico específico de tiempo, puede ser necesario utilizar herramientas adicionales. MongoDB implementó la colección de Time Series, y Elastic también tiene su solución para series temporales implementado. |
# | Consistencia de Datos  | Garantizan la consistencia de los datos a nivel de documento. Tanto MongoDB como Elastic están orientados a la consistencia de datos más que a la disponibilidad.                               |
# | Particionado           | Pueden particionar datos horizontalmente para manejar grandes volúmenes de información. Esto permite distribuir la carga de trabajo entre varios servidores.                                                  |
# | Escalabilidad          | Son generalmente escalables y pueden manejar un crecimiento constante de datos escalando horizontalmente según sea necesario.                                                                   |
#
#
# En conclusión, para mi caso de uso, una base de datos de documentos es apropiada, dada su consistencia, flexibilidad y escalabilidad. Estas bases de datos permiten una gestión ágil de datos, adaptándose a la inclusión de series temporales. Además, su capacidad de particionado y escalabilidad horizontal facilita el manejo de grandes volúmenes de información, asegurando que el sistema pueda expandirse y adaptarse a medida que aumente la cantidad de datos generados. Esta flexibilidad y escalabilidad ofrecen una base sólida para abordar los desafíos de análisis en un entorno que pueda tener cambios como el caso de estudio planteado.
#
#
# <u>MongoDB vs Elasticsearch</u>
#
# Tanto MongoDB como Elasticsearch podrían ser opciones a utilizar en la implementación de nuestro caso de uso. Hay que tener en cuenta que cada sistema fue diseñado con un propósito diferente. Elasticsearch fue diseñado originalmente para soportar la búsqueda de texto completo, y proporciona características avanzadas para ello. También se utiliza habitualmente para el análisis de logs, formando parte de la popular pila Elasticsearch, Logstash y Kibana (ELK). Por otra parte, MongoDB es más adecuado para gestionar datos NoSQL que requieren operaciones de creación, lectura, actualización y eliminación (CRUD). Ofrece alta escalabilidad, fiabilidad y rendimiento.
#
# Ambas cuentan con las ventajas generales de las bases de datos de documentos y tienen implementaciones específicas para optimizar el trabajo con series temporales. Además, ambas tienen características para soportar también datos geoespaciales, característica que podría ser interesante para otros casos de usos relacionados con nuestros datos.
#
# En esta práctica, debido a las restricciones de tiempo que tengo, optaré por implementar el caso de uso en MongoDB dado que su curva de aprendizaje es inferior, y en mi caso, cuento con más conocimientos en esta base de datos.
#
# Además, MongoDB proporciona un particionado automático, mediante el cual simplemente añadimos nodos al clúster a medida que se van necesitando y el software se encarga de lo demás. Su impelementación de series temporales utiliza una gestión basada en Familias de Columnas, siendo transparente para el usuario pero ofreciendo dichas ventajas. Las querys y el indexado de información es potente y completo.
#
#
# **Colas de mensajes (NoSQL)**
#
# Las colas de mensajes son esenciales en arquitecturas de sistemas distribuidos, ya que ofrecen un mecanismo de comunicación asíncrona entre servicios. Funcionan como buffers ligeros que almacenan temporalmente mensajes, permitiendo a los componentes de software producir y consumir información de manera eficiente. Estos mensajes suelen ser pequeños y pueden variar desde solicitudes y respuestas hasta mensajes de error o simplemente datos informativos. Su flexibilidad y capacidad para gestionar la comunicación entre diferentes partes de un sistema hacen que las bases de datos de colas de mensajes sean fundamentales en el desarrollo de sistemas robustos y escalables.
#
# Las colas de mensajes están orientadas a la comunicación entre componentes de software, actuando como un buffer temporal para mensajes entre publicadores y suscriptores, lo cual no tiene nada que ver con nuestro caso de uso. Esta base de datos queda descartada dado la no adecuación de su propósito.
#
#
# **Grafos (NoSQL)**
#
# Un sistema de base de datos de grafos se basa en el modelo de datos de grafos, donde los datos se representan como nodos, relaciones y propiedades. Cada nodo y relación puede contener propiedades que describen características adicionales de los elementos del grafo. Este enfoque permite representar y consultar relaciones complejas entre entidades de datos de manera eficiente. Un ejemplo de este tipo es Neo4j.
#
# Debido a que las bases de datos de grafos están diseñadas específicamente para modelar y consultar relaciones entre entidades, y esto no es necesario en nuestro caso de uso, esta base de datos también queda descartada.
#
#
#
# ## Modelado de datos
#
# Esta sección describe el proceso de modelado de datos llevado a cabo. Al definir este modelo, se han tenido en cuenta los objetivos específicos que deseamos alcanzar. Mi caso de uso se centra en el análisis temporal del contaminante NO2 en estaciones específicas. Para optimizar el rendimiento y la eficiencia de las consultas analíticas, es fundamental tener en mente las preguntas que los usuarios desearán responder a la hora de modelar los datos. Por lo tanto, he diseñado el modelo de datos de manera ascendente, considerando las agregaciones necesarias para el análisis, las particiones requeridas y la indexación adecuada.
#
# **Preguntas que el usuario desea abordar:**
#
# Las preguntas clave que he identificado incluyen:
#
# - Calcular el promedio de concentración de NO2 durante un período determinado (como meses o días) y para diferentes agrupaciones de datos (como los correspondientes a un período específico y a una estación particular).
# - Observar la evolución horaria de las mediciones de NO2 durante un intervalo de tiempo y en una o varias estaciones.
#
# Al realizar el modelado de datos, he seguido un enfoque iterativo, explorando varias versiones y evaluando las ventajas y desventajas de cada una. Además, he trabajado en la mitigación de posibles limitaciones identificadas en el proceso.
#
#
#
# ### Primera iteración
#
# En la primera iteración, inicié el proceso utilizando las tablas proporcionadas por la Comunidad de Madrid. Al analizar los datos originales, identifiqué dos tipos de tablas, cada una con los siguientes campos:
#
#
# | Tabla                    | Campos                               |
# |--------------------------|-------------------------------------------|
# | **Mediciones**           |  Provincia, Municipio, Estación, Magnitud, Punto de muestreo, Año, Mes, Día, Mediciones por horas, Validez de cada una de las mediciones   |
# | **Estaciones de medición**           |  Código, Código corto, Estación, Dirección, Longitud ETRS89, Latitud ETRS89, Altitud, Codigo tipo, Nombre tipo, NO2, SO2, CO, PM10, PM2_5, O3, BTX, Código vía, Vía clase, Vía par, Vía nombre, Fecha alta, Coordenada X ETRS89, Coordenada Y ETRS89, Longitud, Latitud   |
#
#
# En un principio, vemos que las mediciones incluyen cierta información de las estaciones de medición. Basándome en esto, consideré la posibilidad de incorporar la información de las estaciones de medicion en las mediciones diarias. Sin embargo, inmediatamente concluí que no sería una buena idea. Incorporar esta información causaría una gran redundancia, ya que la información de las estaciones estaría duplicada en cada medición. Esto complicaría significativamente el mantenimiento de los datos y resultaría en un aumento drástico del volumen de datos. Los costes asociados con el mantenimiento serían mucho mayores que cualquier beneficio potencial derivado de las lecturas.
#
#
# Por lo tanto, al descartar esa opción, consideré que tendría sentido incorporar las mediciones en estaciones, ya que cada estación puede tener varias mediciones al día y de varios contaminantes. Sin embargo, la cantidad de mediciones sería considerablemente grande debido a la generación de una medición cada hora, y dado que el límite de tamaño del documento es de 16 MB, esto nos llevaría a la necesidad de dividir las mediciones asociadas a una misma estación en diferentes documentos. Esta división podría basarse en algún criterio, como un día y un contaminante específico, donde cada documento de mediciones contendría todas las mediciones respectivas para un contaminante en un día y una estación de medición determinados, junto con su información correspondiente sobre la estación de medición.
#
# Consideré que esta segunda opción era la más adecuada en este punto. Sin embargo, aún así, no me parecía completamente adecuado mantener la información de las estaciones de medición dentro de cada documento de mediciones diarias, debido a que tendríamos la información de las estaciones duplicada múltiples veces (una por cada día). De nuevo, nos enfrentaríamos al problema de los costes de mantenimiento elevados, dado que el conjunto de datos es considerablemente grande.
#
# Por tanto, decidí crear dos colecciones distintas de datos: una para almacenar las mediciones y otra para las estaciones de medición, estableciendo referencias entre ambas. En la colección de mediciones, guardé únicamente la información mínima necesaria para registrar una medición de un contaminante en una estación, asegurándome de incluir una referencia a la estación de medición correspondiente. Mientras tanto, en la colección de estaciones de medición, almacené todos los campos relacionados con estas estaciones.
#
# Así es como se estructuraban mis datos después de la primera iteración del modelado:
#
# Mediciones:
#
# ```
# {'_id': ObjectId('65ed708755ccd84ddbb4b110'),
#  'fecha': {'ano': '2023', 'dia': '01', 'mes': '04'},
#  'info_estacion': {'estacion': 'Plaza de España',
#                    'punto_muestreo': '28079004_1_38'},
#  'magnitud': 'so2',
#  'mediciones': {'h01': 1.0, 'h02': 1.0, 'h03': 1.0, 'h04': 1.0, 'h05': 1.0, 'h06': 1.0, 'h07': 1.0, 'h08': 1.0,
#                 'h09': 1.0, 'h10': 1.0, 'h11': 1.0, 'h12': 1.0, 'h13': 1.0, 'h14': 1.0, 'h15': 1.0, 'h16': 1.0,
#                 'h17': 1.0, 'h18': 1.0, 'h19': 1.0, 'h20': 1.0, 'h21': 1.0, 'h22': 1.0, 'h23': 1.0, 'h24': 1.0}}
# ```
#
# Vemos que cada documento corresponde a un día concreto del año, una estación en concreta y una magnitud de medida. Los resultados de las mediciones están marcadas con el código `hxx` por horas. Únicamente se almacenan los resultados válidos, habiendo eliminado todos los datos relativos a si las mediciones son válidas o no, así como las mediciones inválidas. El campo `"info_estacion.estacion"` es la referencia que se utilizará para buscar la estación de medición en la otra colección.
#
# Estaciones de medición:
#
# ```
# {'_id': ObjectId('65edeff655ccd84ddbba75f6'),
#  'codificacion': {'codigo': '28079004',
#                   'codigo_corto': '4',
#                   'municipio': '079',
#                   'provincia': '28'},
#  'estacion': 'Plaza de España',
#  'fecha alta': '01/12/1998',
#  'magnitudes_de_medida': {'btx': False,
#                           'co': True,
#                           'no2': True,
#                           'o3': False,
#                           'pm10': False,
#                           'pm2_5': False,
#                           'so2': True},
#  'tipo_estacion': {'cod_tipo': 'UT', 'nom_tipo': 'Urbana tráfico'},
#  'ubicacion': {'altitud': 637.0,
#                'cod_via': '273600',
#                'coordenadas': {'coordenada_x_etrs89': 439579.3291,
#                                'coordenada_y_etrs89': 4475049.263,
#                                'latitud': 40.4238823,
#                                'latitud_etrs89': '"40°25\'25.98""N"',
#                                'longitud': -3.7122567,
#                                'longitud_etrs89': '"3°42\'43.91""O"'},
#                'direccion': 'Plaza de España',
#                'via_clase': 'PLAZA',
#                'via_nombre': 'ESPAÑA',
#                'via_par': 'DE'}}
# ```
#
# En este caso, cada documento corresponde a la información de una estación concreta. En ella, se detallan datos sobre el tipo de la estación, ubicación y maginitudes de medida que toma dicha estación. Se han creado jerarquías para agrupar y organizar la información. El campo `"estacion"` contiene valores únicos y es el que se utiliza para vincular con las correspondientes mediciones.
#
# En cuanto a la manera de implementar las referencias, vi que había varias formas de hacer. Se podía utilizar 'ObjectId' o un valor único de campo, tal y como lo he hecho yo con el valor de campo `"info_estacion.estacion"`.
#
# El 'ObjectId' es un identificador único generado automáticamente por MongoDB para cada documento insertado en una colección, garantiza la unicidad por diseño. Además, MongoDB proporciona soporte nativo para trabajar con 'ObjectId', incluida la indexación eficiente y la capacidad de referencia cruzada entre colecciones. Aunque sean muchas las ventajas, vi que aportaba poca información, a no ser que se consulte la colección de estaciones para extraer más datos. De lo contrario, el valor que yo he empleado es también un valor único, y a su vez, es descriptivo y aporta la información necesaria para nuestro caso de uso. Como el objetivo de este modelo de datos es suplir nuestro caso de uso, me decanté por tener una referencia que a su vez sea descriptiva, en vez de un 'ObjectId', y así, evitar tener que realizar consultas adicionales a la colección de las estaciones de medicion.
#
#
# ### Segunda iteración
#
# Tras el primer modelado de datos, realicé pruebas de consultas a la base de datos, basándome en que en mi caso de uso necesito calcular el promedio de NO2 en diferentes periodos de tiempo (como meses, semanas o días), o iterar sobre los resultados obtenidos por horas para ver cómo cambian según el transcurso de tiempo. Detecté que mi modelo actual mostraba dos dificultades:
# 1. La fecha no tenía un formato de fecha, sino que estaba incluido como un JSON compuesto por diferentes String-s, y por tanto, resultaba difícil manejarla a la hora de realizar operaciones con órden cronológico, hacer consultas de rangos de fecha, etc.
# 2. Las mediciones estaban guardadas en un JSON con un formato poco estándar, que nos llevaba a realizar operaciones complejas. Por ejemplo, había que hacer operaciones como transformar la clave "h01" eliminando la h y convirtiendolo a formato número para extraer la hora a la que correspondía la medición.
#
# Ante estas dificultades y reconociendo la necesidad evidente de una gestión eficaz de series temporales en mi caso de uso, decidí investigar sobre la implementación de Series Temporales en MongoDB y explorar las ventajas que ello conlleva.
#
# MongoDB brinda la opción de utilizar colecciones de series temporales. Las colecciones de series temporales utilizan un formato de almacenamiento columnar subyacente, transparente para el usuario, y almacenan los datos en orden temporal. Este formato ofrece las siguientes ventajas:
# - Menor complejidad para trabajar con datos de series temporales
# - Mejora de la eficacia de las consultas
# - Reducción del uso del disco
# - Reducción de la E/S en las operaciones de lectura
# - Mayor uso de la caché WiredTiger
#
# En la versión MongoDB 6.3 y posteriores, además, crean automáticamente un índice compuesto en los campos de tiempo y metadatos para las colecciones de series temporales, mejorando la eficiencia.
#
# Para la implementación de series temporales, fue necesario modificar la estructura de la colección de mediciones, que almacena datos temporales. Esta modificación del modelo de datos implicó una reestructuración significativa, y el resultado fue el siguiente:
#
#
# ```
# {'_id': ObjectId('65f023876ddb1594807f9fdb'),
#  'medicion': 1.0,
#  'metadata': {'estacion': 'Plaza de España',
#               'magnitud': 'so2',
#               'punto_muestreo': '28079004_1_38'},
#  'timestamp': datetime.datetime(2023, 1, 1, 0, 0)}
# ```
#
# En el primer modelo de datos, cada documento representaba un día completo de mediciones para una estación y una magnitud específicas, con las mediciones desglosadas por horas. Sin embargo, ahora, cada documento representa una medición individual en una estación para una magnitud específica, con un registro único para cada hora del día. Esta reestructuración simplifica el modelo al eliminar la necesidad de tener un conjunto de mediciones por día y permite un acceso más granular a los datos de mediciones, lo que facilita consultas específicas y análisis detallados.
#
# Cabe mencionar que decidí conservar el campo `'punto_muestreo'` en las mediciones, ya que este código hace referencia al instrumento utilizado en la medición, es por tanto un dato específico de la medición.
#
# A continuación, procedí a realizar pruebas de consultas en función de los requisitos de mi caso de uso. Esto incluyó la realización de agregaciones de datos en varios rangos de tiempo y el análisis de resultados de mediciones individuales obtenidas por hora. Durante estas pruebas, observé que el nuevo modelo de datos simplificaba considerablemente este tipo de consultas y resultaba adecuado para satisfacer los requisitos del caso de uso.
#
#
# ### Diagrama de modelo de datos final
#
# A continuación se muestra el diagrama de modelo de datos final:
#
# ![Modelo de datos](./data/Modelo_de_datos.png")
#
# Nota: El modelado de datos geoespaciales en la estructura proporcionada podría ser mejorado implementando características de gestión geoespacial en MongoDB para ofrecer una mejor gestión de la ubicación de las estaciones. Sin embargo, en este caso, se ha optado por una estructura más simplificada debido a limitaciones de tiempo de la práctica y a que no es esencial para el caso de uso definido.

# %% [markdown]
# ## Inserción de datos en el modelo
#
# ### Fuentes de datos
# El conjunto de datos se ha obtenido del portal de datos abiertos del Ayuntamiento de Madrid.
#
# - [**Datos de mediciones de la calidad del aire**](https://datos.madrid.es/sites/v/index.jsp?vgnextoid=f3c0f7d512273410VgnVCM2000000c205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD): Información recogida por las estaciones de control de calidad del aire, con los datos horarios por anualidades desde 2001.
#     - Los datos horarios de las magnitudes corresponden a la media aritmética de los valores diezminutales que se registran cada hora.
#
#
# - [**Datos de las estaciones de medida**](https://datos.madrid.es/sites/v/index.jsp?vgnextoid=9e42c176313eb410VgnVCM1000000b205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD): Tabla descriptiva de las estaciones remotas, contiene ubicación, tipos de sensores y fechas de alta.
#     - El Sistema de Vigilancia está formado por 24 estaciones remotas automáticas que recogen la información básica para la vigilancia atmosférica. Poseen los analizadores necesarios para la medida correcta de los niveles de gases y de partículas.
#     - Las estaciones remotas son de varios tipos:
#         - **Urbanas de fondo**: Representativas de la exposición de la población urbana en general.
#         - **De tráfico**: Situadas de tal manera que su nivel de contaminación está influido principalmente por las emisiones procedentes de una calle o carretera próxima, pero se ha de evitar que se midan microambientes muy pequeños en sus proximidades.
#         - **Suburbanas**: Están situadas a las afueras de la ciudad, en los lugares donde se encuentran los mayores niveles de ozono.
#
#
# - [**Interpretación de los datos**](https://datos.madrid.es/FWProjects/egob/Catalogo/MedioAmbiente/Aire/Ficheros/Interprete_ficheros_%20calidad_%20del_%20aire_global.pdf): fichero PDF donde describe el significado de cada columna en los ficheros anteriores. Información relevante a destacar:
#     - **Datos de mediciones de calidad del aire**:
#         - **H0X** corresponde al dato de la X de la mañana de ese día.
#         - **V0X** es el código de validación. Únicamente son válidos los datos que llevan el código de validación "V".
#         - **Magnitud**: El anexo II mapea las magnitudes, sus unidades y técnicas de medida con los respectivos códigos.
#     - **Datos de las estaciones de medida**: Incluye una tabla con los datos sobre los códigos de las estaciones y señala los cambios de código a lo largo de los años.
#
#
# Los datos utilizados en esta práctica han sido descargados desde los enlaces listados anteriormente, y están guardados en la carpeta `work/practica/data`.

# %% [markdown]
# ### Ingesta de datos
#
# Primero instalamos `pymongo`, creamos la conexión a la base de datos y creamos tanto la base de datos como la colección que utilizaremos.

# %%
# Instalar pymongo o comprobar que esté instalado
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /opt/conda/lib/python3.6/site-packages (3.10.1)

# %%
# Importación del módulo pymongo y de la clase MongoClient
import pymongo
from pymongo import MongoClient

# Conexión con la base de datos
client = MongoClient('mongodb://nosql:nosql@mongo:27017/')

# Limpiar el entorno de anteriores ejecuciones
client.drop_database("practica_maialen")

# %%
# Crear la base de datos para la práctica
db = client["practica_maialen"]

# %% [markdown]
# #### Importar los datos de las mediciones de la calidad de aire
#
# Ahora nos disponemos a importar los datos. En un pipeline de big data, la ingestión de datos se lleva a cabo en diversas etapas, siguiendo el **ciclo de vida del dato**. En la primera etapa de importación a la base de datos, los datos se capturan tal como están, sin ser modificados ni manipulados, lo que se conoce como una importación "raw" de los datos en bruto. Posteriormente, los datos atraviesan diversas etapas de ingeniería de datos, donde son refinados y transformados.
#
# En este contexto, nuestra etapa RAW implica guardar los datos en la carpeta `work/practica/data` en formato CSV, conservando su estructura original. Dado que ya contamos con un modelo de datos definido, durante la fase de ingestión de datos a MongoDB, aprovecharemos para transformarlos y almacenarlos directamente en formato JSON, adaptándolos al modelo de datos definido y realizando las limpiezas y transformaciones necesarias. Este proceso nos permitirá obtener lo que se conoce como una base de datos GOLD, donde los datos se encuentran limpios y listos para su análisis.
#
# En este caso, he considerado que es conveniente unificar los pasos de ingestión de datos crudos y limpieza en una misma etapa por razones prácticas, ya que se trata de un proyecto con un alcance definido, y agiliza el desarrollo y reduce los tiempos de ejecución del proceso.

# %%
# Crear la colección "air_quality" que es una time series donde se almacenan las mediciones de la calidad del aire
air_quality_collection = db.create_collection(
        "air_quality",
        timeseries= {
                "timeField": "timestamp",
                "metaField": "metadata",
                "granularity": "hours"  # seconds, minutes or hours
                }
    )

# %%
# Metodo para mapear códigos de magnitudes con sus correspondientes descripciones
def format_magnitud(magnitud_to_be_formated):

    mapping_magintud = {
            1: 'so2',  # Dióxido de azufre
            6: 'co',  # Monóxido de carbono
            7: 'no',  # Monóxido de nitrógeno
            8: 'no2',  # Dióxido de nitrógeno
            9: 'pm2_5',  # Partículas superiores a 2.5 micrometros
            10: 'pm10',  # Partículas superiores a 10 micrometros
            12: 'nox',  # Óxidos de nitrógeno
            14: 'o3',  # Ozono
            20: 'tol',  # Tolueno
            30: 'ben',  # Benceno
            35: 'ebe'  # Etilbenceno
        }

    
    return mapping_magintud[magnitud_to_be_formated]

# %%
# Método para mapear los códigos de las estaciones con los valores correspondientes
def format_estacion(estacion_to_be_formated):
    
    
    mapping_estacion = {
        4: "Plaza de España",
        8: "Escuelas Aguirre",
        11: "Ramón y Cajal",
        16: "Arturo Soria",
        17: "Villaverde",
        18: "Farolillo",
        24: "Casa de Campo",
        27: "Barajas Pueblo",
        35: "Plaza del Carmen",
        36: "Moratalaz",
        38: "Cuatro Caminos",
        39: "Barrio del Pilar",
        40: "Vallecas",
        47: "Méndez Álvaro",
        48: "Castellana",
        49: "Parque del Retiro",
        50: "Plaza Castilla",
        54: "Ensanche de Vallecas",
        55: "Urb. Embajada",
        56: "Plaza Elíptica",
        57: "Sanchinarro",
        58: "El Pardo",
        59: "Juan Carlos I",
        60: "Tres Olivos"
    }
    return mapping_estacion[estacion_to_be_formated]

# %%
import pandas as pd
from pandas import Timestamp

# Método para ingestar un archivo CSV de datos de mediciones
def ingest_file(file_path):
    # Lee el archivo CSV y crea un DataFrame
    df = pd.read_csv(file_path, delimiter=';')

    
    # Pada cada fila (día) y cada hora, crear el JSON e insertar a la base de datos

    # Para cada fila (día)
    for index, row in df.iterrows(): 

        list_of_json_per_day = []

        # Para cada hora
        for i in range(1, 25):
            hora_string = str(i).zfill(2) if i < 10 else str(i)

            # Si el dato es válido
            if row['V'+hora_string] == 'V':
                
                # Construimos el JSON de la medicion
                json_data = {
                    'timestamp': Timestamp(f"{str(row['ANO'])}-{str(row['MES'])}-{str(row['DIA'])} {i-1}:00:00"),
                    'metadata': {
                        'estacion': format_estacion(row['ESTACION']),
                        'punto_muestreo': str(row['PUNTO_MUESTREO']),
                        'magnitud': format_magnitud(row['MAGNITUD'])
                    },
                    'medicion': row['H'+hora_string]
                }

                # Añadimos el JSON a la lista de JSONs
                list_of_json_per_day.append(json_data)

        # Insertamos los datos de un día a la base de datos
        if len(list_of_json_per_day) > 0:
            air_quality_collection.insert_many(list_of_json_per_day)

# %%
import os

# Obtener la lista de archivos en la carpeta
files = os.listdir("./data/air_quality")

# Para cada archivo, cargar los datos
for file in files:
    # Ruta al archivo CSV
    csv_file = './data/air_quality/' + file
    
    ingest_file(csv_file)

# %% [markdown]
# Una vez insertados todos los datos de las mediciones, verificaremos que los datos se han incorporado a la base de datos de MongoDB de manera correcta, haciendo consultas sobre los datos importados:

# %%
import pprint

# Recupera 5 documentos de la colección
documentos = air_quality_collection.find().limit(5)

# Itera sobre los documentos e imprime su contenido
for documento in documentos:
    pprint.pprint(documento)
# Out:
# {'_id': ObjectId('65f0a6e56ddb159480d470f6'),
#  'medicion': 1.0,
#  'metadata': {'estacion': 'Plaza de España',
#               'magnitud': 'so2',
#               'punto_muestreo': '28079004_1_38'},
#  'timestamp': datetime.datetime(2023, 1, 1, 0, 0)}
# {'_id': ObjectId('65f0a6e56ddb159480d470f7'),
#  'medicion': 3.0,
#  'metadata': {'estacion': 'Plaza de España',
#               'magnitud': 'so2',
#               'punto_muestreo': '28079004_1_38'},
#  'timestamp': datetime.datetime(2023, 1, 1, 1, 0)}
# {'_id': ObjectId('65f0a6e56ddb159480d470f8'),
#  'medicion': 3.0,
#  'metadata': {'estacion': 'Plaza de España',
#               'magnitud': 'so2',
#               'punto_muestreo': '28079004_1_38'},
#  'timestamp': datetime.datetime(2023, 1, 1, 2, 0)}
# {'_id': ObjectId('65f0a6e56ddb159480d470f9'),
#  'medicion': 2.0,
#  'metadata': {'estacion': 'Plaza de España',
#               'magnitud': 'so2',
#               'punto_muestreo': '28079004_1_38'},
#  'timestamp': datetime.datetime(2023, 1, 1, 3, 0)}
# {'_id': ObjectId('65f0a6e56ddb159480d470fa'),
#  'medicion': 1.0,
#  'metadata': {'estacion': 'Plaza de España',
#               'magnitud': 'so2',
#               'punto_muestreo': '28079004_1_38'},
#  'timestamp': datetime.datetime(2023, 1, 1, 4, 0)}

# %% [markdown]
# #### Importar datos de las estaciones de medida
# Ahora importaremos los datos de las estaciones de medida:

# %%
# Método para dar formato al JSON según el modelo de datos
def format_measurement_stations_data(measurement_stations_json):    
    formatted_json = {
        "codificacion": {
            "codigo_corto": measurement_stations_json["codigo_corto"],
            "codigo": measurement_stations_json["codigo"],
            "provincia": measurement_stations_json["codigo"][:2],
            "municipio": measurement_stations_json["codigo"][2:5]
        },
        "estacion": measurement_stations_json["estacion"],
        "ubicacion": {
            'direccion': measurement_stations_json["direccion"],
            'via_clase': measurement_stations_json["via_clase"],
            'via_par': measurement_stations_json["via_par"],
            'via_nombre': measurement_stations_json["via_nombre"],
            'coordenadas': {
                'longitud_etrs89': measurement_stations_json["longitud_etrs89"],
                'latitud_etrs89': measurement_stations_json["latitud_etrs89"],
                'coordenada_x_etrs89': float(measurement_stations_json["coordenada_x_etrs89"].replace(",", ".")),
                'coordenada_y_etrs89': float(measurement_stations_json["coordenada_y_etrs89"].replace(",", ".")),
                'longitud': float(measurement_stations_json["longitud"]),
                'latitud': float(measurement_stations_json["latitud"])
            },
            'altitud': float(measurement_stations_json["altitud"]),
            'cod_via': measurement_stations_json["cod_via"]
        },
        'tipo_estacion': {
            'cod_tipo': measurement_stations_json["cod_tipo"],
            'nom_tipo': measurement_stations_json["nom_tipo"]
        },
        'magnitudes_de_medida': {
            'no2': measurement_stations_json["no2"] == 'X',
            'so2': measurement_stations_json["so2"] == 'X',
            'co': measurement_stations_json["co"] == 'X',
            'pm10': measurement_stations_json["pm10"] == 'X',
            'pm2_5': measurement_stations_json["pm2_5"] == 'X',
            'o3': measurement_stations_json["o3"] == 'X',
            'btx': measurement_stations_json["btx"] == 'X'
        },
        'fecha alta': measurement_stations_json["fecha alta"]
    }
    
    return formatted_json

# %%
# Crear la colección "measurement_stations"
measurement_stations_collection = db["measurement_stations"]

# Ruta al archivo CSV
csv_file = './data/informacion_estaciones_red_calidad_aire.csv'

# Lectura del archivo CSV y carga de datos en la base de datos
with open(csv_file, 'r') as file:
    header = file.readline().strip().replace('\ufeff', '').lower().split(';')  # Creamos el encabezado

    # Insertar datos en la colección
    for each_value in file:
        value_list = each_value.strip().split(';')
        row = dict(zip(header, value_list))  # Creamos el diccionario combinando el encabezado con los valores
        formatted_row = format_measurement_stations_data(row)  # Formateamos

        # Insertar cada fila como un documento en la colección
        measurement_stations_collection.insert_one(formatted_row)

# %%
# Obtener 3 documentos de la colección
documents = measurement_stations_collection.find().limit(3)

# Imprimir los documentos
for doc in documents:
    pprint.pprint(doc)
    print()
# Out:
# {'_id': ObjectId('65f0a7fd6ddb159480e108c1'),
#  'codificacion': {'codigo': '28079004',
#                   'codigo_corto': '4',
#                   'municipio': '079',
#                   'provincia': '28'},
#  'estacion': 'Plaza de España',
#  'fecha alta': '01/12/1998',
#  'magnitudes_de_medida': {'btx': False,
#                           'co': True,
#                           'no2': True,
#                           'o3': False,
#                           'pm10': False,
#                           'pm2_5': False,
#                           'so2': True},
#  'tipo_estacion': {'cod_tipo': 'UT', 'nom_tipo': 'Urbana tráfico'},
#  'ubicacion': {'altitud': 637.0,
#                'cod_via': '273600',
#                'coordenadas': {'coordenada_x_etrs89': 439579.3291,
#                                'coordenada_y_etrs89': 4475049.263,
#                                'latitud': 40.4238823,
#                                'latitud_etrs89': '"40°25\'25.98""N"',
#                                'longitud': -3.7122567,
#                                'longitud_etrs89': '"3°42\'43.91""O"'},
#                'direccion': 'Plaza de España',
#                'via_clase': 'PLAZA',
#                'via_nombre': 'ESPAÑA',
#                'via_par': 'DE'}}
#
# {'_id': ObjectId('65f0a7fd6ddb159480e108c2'),
#  'codificacion': {'codigo': '28079008',
#                   'codigo_corto': '8',
#                   'municipio': '079',
#                   'provincia': '28'},
#  'estacion': 'Escuelas Aguirre',
#  'fecha alta': '01/12/1998',
#  'magnitudes_de_medida': {'btx': True,
#                           'co': True,
#                           'no2': True,
#                           'o3': True,
#                           'pm10': True,
#                           'pm2_5': True,
#                           'so2': True},
#  'tipo_estacion': {'cod_tipo': 'UT', 'nom_tipo': 'Urbana tráfico'},
#  'ubicacion': {'altitud': 672.0,
#                'cod_via': '18900',
#                'coordenadas': {'coordenada_x_etrs89': 442117.2366,
#                                'coordenada_y_etrs89': 4474770.696,
#                                'latitud': 40.4215533,
#                                'latitud_etrs89': '"40°25\'17.63""N"',
#                                'longitud': -3.6823158,
#                                'longitud_etrs89': '"3°40\'56.22""O"'},
#                'direccion': 'Entre C/ Alcalá y C/ O’ Donell ',
#                'via_clase': 'CALLE',
#                'via_nombre': 'ALCALA',
#                'via_par': 'DE'}}
#
# {'_id': ObjectId('65f0a7fd6ddb159480e108c3'),
#  'codificacion': {'codigo': '28079011',
#                   'codigo_corto': '11',
#                   'municipio': '079',
#                   'provincia': '28'},
#  'estacion': 'Ramón y Cajal',
#  'fecha alta': '01/12/1998',
#  'magnitudes_de_medida': {'btx': True,
#                           'co': False,
#                           'no2': True,
#                           'o3': False,
#                           'pm10': False,
#                           'pm2_5': False,
#                           'so2': False},
#  'tipo_estacion': {'cod_tipo': 'UT', 'nom_tipo': 'Urbana tráfico'},
#  'ubicacion': {'altitud': 708.0,
#                'cod_via': '610450',
#                'coordenadas': {'coordenada_x_etrs89': 442564.0457,
#                                'coordenada_y_etrs89': 4478088.595,
#                                'latitud': 40.4514734,
#                                'latitud_etrs89': '"40°27\'5.29""N"',
#                                'longitud': -3.6773491,
#                                'longitud_etrs89': '"3°40\'38.50""O"'},
#                'direccion': 'Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara',
#                'via_clase': 'CALLE',
#                'via_nombre': 'PRINCIPE DE VERGARA',
#                'via_par': 'DEL'}}

# %% [markdown]
# ## Sentencias de consulta
#
# Esta sección detalla las consultas realizadas en el proyecto. Comenzaremos con algunas consultas destinadas a explorar el conjunto de datos en su totalidad, abordando cuestiones generales que no se relacionan directamente con el caso de uso específico. Luego, nos centraremos en las consultas diseñadas para nuestro caso de uso particular, que incluyen agregaciones, así como detalles sobre indexación y particionado de los datos.
#
#
#
# ### Exploración general
# El propósito es obtener una comprensión global de los datos almacenados en nuestra base de datos. Para lograr esto, examinaremos el recuento total de mediciones para cada contaminante:

# %%
# Operación de agregación para contar documentos por magnitud
pipeline = [
    {
        "$group": {
            "_id": "$metadata.magnitud",
            "total_mediciones": {"$sum": 1}
        }
    },
    {
        "$sort": {"total_mediciones": -1}  # Ordenar en orden descendente por total_mediciones
    }
]

# Ejecutar la operación de agregación
results = air_quality_collection.aggregate(pipeline)

# Imprimir los resultados
for doc in results:
    print(doc)
# Out:
# {'_id': 'nox', 'total_mediciones': 203833}
# {'_id': 'no', 'total_mediciones': 203833}
# {'_id': 'no2', 'total_mediciones': 203833}
# {'_id': 'pm10', 'total_mediciones': 110666}
# {'_id': 'o3', 'total_mediciones': 110516}
# {'_id': 'pm2_5', 'total_mediciones': 67903}
# {'_id': 'ben', 'total_mediciones': 49039}
# {'_id': 'ebe', 'total_mediciones': 48857}
# {'_id': 'tol', 'total_mediciones': 48311}
# {'_id': 'co', 'total_mediciones': 32511}
# {'_id': 'so2', 'total_mediciones': 31223}

# %% [markdown]
# Vemos que los contaminantes que más se han medido han sido el NO, NO2 y NOX. Ahora veremos cómo se han distribuido dichas mediciones en las estaciones:

# %%
# Consulta para agrupar y contar la frecuencia de cada valor de "magnitud" en cada estación
pipeline = [
    {"$group": {
        "_id": {"magnitud": "$metadata.magnitud", "estacion": "$metadata.estacion"},
        "total_mediciones": {"$sum": 1}
    }},
    {"$sort": {"_id.magnitud": 1, "_id.estacion": 1}}
]

# Ejecutar la consulta
result = air_quality_collection.aggregate(pipeline)

# Imprimir los resultados
for doc in result:
    print(doc)
# Out:
# {'_id': {'magnitud': 'ben', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8561}
# {'_id': {'magnitud': 'ben', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8494}
# {'_id': {'magnitud': 'ben', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8481}
# {'_id': {'magnitud': 'ben', 'estacion': 'Farolillo'}, 'total_mediciones': 7806}
# {'_id': {'magnitud': 'ben', 'estacion': 'Ramón y Cajal'}, 'total_mediciones': 7213}
# {'_id': {'magnitud': 'ben', 'estacion': 'Urb. Embajada'}, 'total_mediciones': 8484}
# {'_id': {'magnitud': 'co', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8645}
# {'_id': {'magnitud': 'co', 'estacion': 'Plaza Elíptica'}, 'total_mediciones': 8668}
# {'_id': {'magnitud': 'co', 'estacion': 'Plaza de España'}, 'total_mediciones': 8646}
# {'_id': {'magnitud': 'co', 'estacion': 'Plaza del Carmen'}, 'total_mediciones': 6552}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8512}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8407}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8410}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Farolillo'}, 'total_mediciones': 7771}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Ramón y Cajal'}, 'total_mediciones': 7290}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Urb. Embajada'}, 'total_mediciones': 8467}
# {'_id': {'magnitud': 'no', 'estacion': 'Arturo Soria'}, 'total_mediciones': 8695}
# {'_id': {'magnitud': 'no', 'estacion': 'Barajas Pueblo'}, 'total_mediciones': 8675}
# {'_id': {'magnitud': 'no', 'estacion': 'Barrio del Pilar'}, 'total_mediciones': 8631}
# {'_id': {'magnitud': 'no', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8232}
# {'_id': {'magnitud': 'no', 'estacion': 'Castellana'}, 'total_mediciones': 8701}
# {'_id': {'magnitud': 'no', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8663}
# {'_id': {'magnitud': 'no', 'estacion': 'El Pardo'}, 'total_mediciones': 8641}
# {'_id': {'magnitud': 'no', 'estacion': 'Ensanche de Vallecas'}, 'total_mediciones': 8673}
# {'_id': {'magnitud': 'no', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8670}
# {'_id': {'magnitud': 'no', 'estacion': 'Farolillo'}, 'total_mediciones': 8650}
# {'_id': {'magnitud': 'no', 'estacion': 'Juan Carlos I'}, 'total_mediciones': 8479}
# {'_id': {'magnitud': 'no', 'estacion': 'Moratalaz'}, 'total_mediciones': 8676}
# {'_id': {'magnitud': 'no', 'estacion': 'Méndez Álvaro'}, 'total_mediciones': 8656}
# {'_id': {'magnitud': 'no', 'estacion': 'Parque del Retiro'}, 'total_mediciones': 8551}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza Castilla'}, 'total_mediciones': 8685}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza Elíptica'}, 'total_mediciones': 8685}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza de España'}, 'total_mediciones': 8667}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza del Carmen'}, 'total_mediciones': 6761}
# {'_id': {'magnitud': 'no', 'estacion': 'Ramón y Cajal'}, 'total_mediciones': 7327}
# {'_id': {'magnitud': 'no', 'estacion': 'Sanchinarro'}, 'total_mediciones': 8680}
# {'_id': {'magnitud': 'no', 'estacion': 'Tres Olivos'}, 'total_mediciones': 8463}
# {'_id': {'magnitud': 'no', 'estacion': 'Urb. Embajada'}, 'total_mediciones': 8627}
# {'_id': {'magnitud': 'no', 'estacion': 'Vallecas'}, 'total_mediciones': 8699}
# {'_id': {'magnitud': 'no', 'estacion': 'Villaverde'}, 'total_mediciones': 8646}
# {'_id': {'magnitud': 'no2', 'estacion': 'Arturo Soria'}, 'total_mediciones': 8695}
# {'_id': {'magnitud': 'no2', 'estacion': 'Barajas Pueblo'}, 'total_mediciones': 8675}
# {'_id': {'magnitud': 'no2', 'estacion': 'Barrio del Pilar'}, 'total_mediciones': 8631}
# {'_id': {'magnitud': 'no2', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8232}
# {'_id': {'magnitud': 'no2', 'estacion': 'Castellana'}, 'total_mediciones': 8701}
# {'_id': {'magnitud': 'no2', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8663}
# {'_id': {'magnitud': 'no2', 'estacion': 'El Pardo'}, 'total_mediciones': 8641}
# {'_id': {'magnitud': 'no2', 'estacion': 'Ensanche de Vallecas'}, 'total_mediciones': 8673}
# {'_id': {'magnitud': 'no2', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8670}
# {'_id': {'magnitud': 'no2', 'estacion': 'Farolillo'}, 'total_mediciones': 8650}
# {'_id': {'magnitud': 'no2', 'estacion': 'Juan Carlos I'}, 'total_mediciones': 8479}
# {'_id': {'magnitud': 'no2', 'estacion': 'Moratalaz'}, 'total_mediciones': 8676}
# {'_id': {'magnitud': 'no2', 'estacion': 'Méndez Álvaro'}, 'total_mediciones': 8656}
# {'_id': {'magnitud': 'no2', 'estacion': 'Parque del Retiro'}, 'total_mediciones': 8551}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza Castilla'}, 'total_mediciones': 8685}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza Elíptica'}, 'total_mediciones': 8685}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza de España'}, 'total_mediciones': 8667}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza del Carmen'}, 'total_mediciones': 6761}
# {'_id': {'magnitud': 'no2', 'estacion': 'Ramón y Cajal'}, 'total_mediciones': 7327}
# {'_id': {'magnitud': 'no2', 'estacion': 'Sanchinarro'}, 'total_mediciones': 8680}
# {'_id': {'magnitud': 'no2', 'estacion': 'Tres Olivos'}, 'total_mediciones': 8463}
# {'_id': {'magnitud': 'no2', 'estacion': 'Urb. Embajada'}, 'total_mediciones': 8627}
# {'_id': {'magnitud': 'no2', 'estacion': 'Vallecas'}, 'total_mediciones': 8699}
# {'_id': {'magnitud': 'no2', 'estacion': 'Villaverde'}, 'total_mediciones': 8646}
# {'_id': {'magnitud': 'nox', 'estacion': 'Arturo Soria'}, 'total_mediciones': 8695}
# {'_id': {'magnitud': 'nox', 'estacion': 'Barajas Pueblo'}, 'total_mediciones': 8675}
# {'_id': {'magnitud': 'nox', 'estacion': 'Barrio del Pilar'}, 'total_mediciones': 8631}
# {'_id': {'magnitud': 'nox', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8232}
# {'_id': {'magnitud': 'nox', 'estacion': 'Castellana'}, 'total_mediciones': 8701}
# {'_id': {'magnitud': 'nox', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8663}
# {'_id': {'magnitud': 'nox', 'estacion': 'El Pardo'}, 'total_mediciones': 8641}
# {'_id': {'magnitud': 'nox', 'estacion': 'Ensanche de Vallecas'}, 'total_mediciones': 8673}
# {'_id': {'magnitud': 'nox', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8670}
# {'_id': {'magnitud': 'nox', 'estacion': 'Farolillo'}, 'total_mediciones': 8650}
# {'_id': {'magnitud': 'nox', 'estacion': 'Juan Carlos I'}, 'total_mediciones': 8479}
# {'_id': {'magnitud': 'nox', 'estacion': 'Moratalaz'}, 'total_mediciones': 8676}
# {'_id': {'magnitud': 'nox', 'estacion': 'Méndez Álvaro'}, 'total_mediciones': 8656}
# {'_id': {'magnitud': 'nox', 'estacion': 'Parque del Retiro'}, 'total_mediciones': 8551}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza Castilla'}, 'total_mediciones': 8685}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza Elíptica'}, 'total_mediciones': 8685}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza de España'}, 'total_mediciones': 8667}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza del Carmen'}, 'total_mediciones': 6761}
# {'_id': {'magnitud': 'nox', 'estacion': 'Ramón y Cajal'}, 'total_mediciones': 7327}
# {'_id': {'magnitud': 'nox', 'estacion': 'Sanchinarro'}, 'total_mediciones': 8680}
# {'_id': {'magnitud': 'nox', 'estacion': 'Tres Olivos'}, 'total_mediciones': 8463}
# {'_id': {'magnitud': 'nox', 'estacion': 'Urb. Embajada'}, 'total_mediciones': 8627}
# {'_id': {'magnitud': 'nox', 'estacion': 'Vallecas'}, 'total_mediciones': 8699}
# {'_id': {'magnitud': 'nox', 'estacion': 'Villaverde'}, 'total_mediciones': 8646}
# {'_id': {'magnitud': 'o3', 'estacion': 'Arturo Soria'}, 'total_mediciones': 8677}
# {'_id': {'magnitud': 'o3', 'estacion': 'Barajas Pueblo'}, 'total_mediciones': 8636}
# {'_id': {'magnitud': 'o3', 'estacion': 'Barrio del Pilar'}, 'total_mediciones': 8623}
# {'_id': {'magnitud': 'o3', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8564}
# {'_id': {'magnitud': 'o3', 'estacion': 'El Pardo'}, 'total_mediciones': 8621}
# {'_id': {'magnitud': 'o3', 'estacion': 'Ensanche de Vallecas'}, 'total_mediciones': 8651}
# {'_id': {'magnitud': 'o3', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8634}
# {'_id': {'magnitud': 'o3', 'estacion': 'Farolillo'}, 'total_mediciones': 8555}
# {'_id': {'magnitud': 'o3', 'estacion': 'Juan Carlos I'}, 'total_mediciones': 8645}
# {'_id': {'magnitud': 'o3', 'estacion': 'Parque del Retiro'}, 'total_mediciones': 8499}
# {'_id': {'magnitud': 'o3', 'estacion': 'Plaza del Carmen'}, 'total_mediciones': 7088}
# {'_id': {'magnitud': 'o3', 'estacion': 'Tres Olivos'}, 'total_mediciones': 8677}
# {'_id': {'magnitud': 'o3', 'estacion': 'Villaverde'}, 'total_mediciones': 8646}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8465}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Castellana'}, 'total_mediciones': 8074}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8572}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8591}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Farolillo'}, 'total_mediciones': 8403}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Moratalaz'}, 'total_mediciones': 8692}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Méndez Álvaro'}, 'total_mediciones': 8523}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Plaza Castilla'}, 'total_mediciones': 8610}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Plaza Elíptica'}, 'total_mediciones': 8532}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Sanchinarro'}, 'total_mediciones': 8591}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Tres Olivos'}, 'total_mediciones': 8604}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Urb. Embajada'}, 'total_mediciones': 8487}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Vallecas'}, 'total_mediciones': 8522}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8407}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Castellana'}, 'total_mediciones': 8080}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8594}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8595}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Méndez Álvaro'}, 'total_mediciones': 8536}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Plaza Castilla'}, 'total_mediciones': 8578}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Plaza Elíptica'}, 'total_mediciones': 8488}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Sanchinarro'}, 'total_mediciones': 8625}
# {'_id': {'magnitud': 'so2', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8534}
# {'_id': {'magnitud': 'so2', 'estacion': 'Moratalaz'}, 'total_mediciones': 7723}
# {'_id': {'magnitud': 'so2', 'estacion': 'Plaza de España'}, 'total_mediciones': 8608}
# {'_id': {'magnitud': 'so2', 'estacion': 'Plaza del Carmen'}, 'total_mediciones': 6358}
# {'_id': {'magnitud': 'tol', 'estacion': 'Casa de Campo'}, 'total_mediciones': 8541}
# {'_id': {'magnitud': 'tol', 'estacion': 'Cuatro Caminos'}, 'total_mediciones': 8443}
# {'_id': {'magnitud': 'tol', 'estacion': 'Escuelas Aguirre'}, 'total_mediciones': 8462}
# {'_id': {'magnitud': 'tol', 'estacion': 'Farolillo'}, 'total_mediciones': 7743}
# {'_id': {'magnitud': 'tol', 'estacion': 'Ramón y Cajal'}, 'total_mediciones': 6779}
# {'_id': {'magnitud': 'tol', 'estacion': 'Urb. Embajada'}, 'total_mediciones': 8343}

# %% [markdown]
# Observamos que no todas las estaciones han registrado mediciones para todos los contaminantes. Además, vemos que el número de mediciones varía entre las estaciones, lo cual se atribuye a la exclusión de mediciones inválidas de cada una.
#
# Estas consultas nos proporcionan una visión general del contenido de nuestra base de datos. Por ejemplo, podemos identificar las magnitudes que han sido más frecuentemente medidas a lo largo del año. Destacamos la abundancia de estaciones que miden el contaminante NO2, lo que confirma la idoneidad de nuestro conjunto de datos para nuestro caso de uso.
#
# Dado que estas consultas son eventuales y no recurrentes, no es necesario invertir tiempo en la creación de índices o en la optimización de este tipo de consultas.

# %% [markdown]
# ### Consultas para nuestro Caso de Uso:
#
# **Caso de uso:** Análisis de la evolución temporal de NO2 en las estaciones de medición de la calidad del aire de Madrid durante 2023.
#
# En concreto, nuestros científicos de datos necesitan información obtenida de tres consultas:
#
# | # | Consulta                                                                                  | Objetivo                                                                                                    |
# |---|--------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|
# | 1 | Promedio de contaminante NO2 por mes medido en cada una de las estaciones en el 2023       | Determinar si existe alguna correlación entre los niveles de NO2 y las épocas del año.                     |
# | 2 | Promedio de contaminante NO2 por día medido en una estación específica en el 2023           | Visualizar la variabilidad de las mediciones día a día de NO2 en una estación particular.                   |
# | 3 | Mediciones de NO2 por horas durante una semana específica en una estación concreta durante el año 2023 | Observar la evolución de los valores de NO2 a lo largo de una semana en una estación concreta para detectar patrones horarias.    |
#
#
#
# #### Consulta 1: Promedio de NO2 por mes en cada estación en el 2023

# %%
# Operación de agregación para calcular la media de la medición por mes y estación
pipeline = [
    {
        "$match": {
            "metadata.magnitud": "no2",  # Filtrar por la magnitud 'no2'
            "timestamp": {  # Filtrar por el año 2023
                "$gte": datetime.datetime(2023, 1, 1), 
                "$lt": datetime.datetime(2024, 1, 1)
            }  
        }
    },
    {
        "$project": {
            "estacion": "$metadata.estacion", # Proyectar el campo 'estacion' de 'metadata'
            "mes": {"$month": "$timestamp"},  # Extraer el mes de la fecha en 'timestamp'
            "medicion": "$medicion"           # Proyectar el campo 'medicion'
        }
    },
    {
        "$group": {
            "_id": {"estacion": "$estacion", "mes": "$mes"},  # Agrupar por estacion y mes
            "media_mensual_medicion": {"$avg": "$medicion"}   # Calcular la media de las mediciones
        }
    },
    {
        "$sort": {
            "_id.estacion": 1,  # Ordenar ascendentemente por estacion
            "_id.mes": 1  # Ordenar ascendentemente por mes
        }
    }
]

# Ejecutar la operación de agregación
result = list(air_quality_collection.aggregate(pipeline))

# Imprimir los resultados
for item in result:
    print(item)
# Out:
# {'_id': {'estacion': 'Arturo Soria', 'mes': 1}, 'media_mensual_medicion': 32.821862348178136}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 2}, 'media_mensual_medicion': 36.93617021276596}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 3}, 'media_mensual_medicion': 28.616531165311653}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 4}, 'media_mensual_medicion': 21.488795518207283}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 5}, 'media_mensual_medicion': 15.161943319838057}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 6}, 'media_mensual_medicion': 20.07262569832402}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 7}, 'media_mensual_medicion': 19.86874154262517}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 8}, 'media_mensual_medicion': 20.044594594594596}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 9}, 'media_mensual_medicion': 28.368200836820083}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 10}, 'media_mensual_medicion': 29.345578231292517}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 11}, 'media_mensual_medicion': 33.70391061452514}
# {'_id': {'estacion': 'Arturo Soria', 'mes': 12}, 'media_mensual_medicion': 41.597297297297295}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 1}, 'media_mensual_medicion': 35.24357239512855}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 2}, 'media_mensual_medicion': 44.59076923076923}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 3}, 'media_mensual_medicion': 31.941655359565807}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 4}, 'media_mensual_medicion': 28.10599721059972}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 5}, 'media_mensual_medicion': 21.87144790257104}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 6}, 'media_mensual_medicion': 26.805359661495064}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 7}, 'media_mensual_medicion': 28.67297297297297}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 8}, 'media_mensual_medicion': 27.886486486486486}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 9}, 'media_mensual_medicion': 36.37342657342657}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 10}, 'media_mensual_medicion': 37.09041835357625}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 11}, 'media_mensual_medicion': 37.91480446927374}
# {'_id': {'estacion': 'Barajas Pueblo', 'mes': 12}, 'media_mensual_medicion': 46.931693989071036}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 1}, 'media_mensual_medicion': 36.470985155195685}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 2}, 'media_mensual_medicion': 40.77554438860972}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 3}, 'media_mensual_medicion': 24.26358695652174}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 4}, 'media_mensual_medicion': 22.556022408963585}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 5}, 'media_mensual_medicion': 15.004065040650406}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 6}, 'media_mensual_medicion': 19.787412587412586}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 7}, 'media_mensual_medicion': 20.721621621621622}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 8}, 'media_mensual_medicion': 19.002695417789756}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 9}, 'media_mensual_medicion': 31.07002801120448}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 10}, 'media_mensual_medicion': 32.92567567567568}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 11}, 'media_mensual_medicion': 31.517482517482517}
# {'_id': {'estacion': 'Barrio del Pilar', 'mes': 12}, 'media_mensual_medicion': 45.910690121786196}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 1}, 'media_mensual_medicion': 20.989174560216508}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 2}, 'media_mensual_medicion': 23.263719512195124}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 3}, 'media_mensual_medicion': 13.778625954198473}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 4}, 'media_mensual_medicion': 11.849507735583686}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 5}, 'media_mensual_medicion': 9.50408719346049}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 6}, 'media_mensual_medicion': 11.461322081575247}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 7}, 'media_mensual_medicion': 9.990514905149052}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 8}, 'media_mensual_medicion': 10.386648122392211}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 9}, 'media_mensual_medicion': 17.577247191011235}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 10}, 'media_mensual_medicion': 17.457259158751697}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 11}, 'media_mensual_medicion': 16.556765163297044}
# {'_id': {'estacion': 'Casa de Campo', 'mes': 12}, 'media_mensual_medicion': 29.039242219215154}
# {'_id': {'estacion': 'Castellana', 'mes': 1}, 'media_mensual_medicion': 35.06630581867388}
# {'_id': {'estacion': 'Castellana', 'mes': 2}, 'media_mensual_medicion': 36.50903614457831}
# {'_id': {'estacion': 'Castellana', 'mes': 3}, 'media_mensual_medicion': 31.50338294993234}
# {'_id': {'estacion': 'Castellana', 'mes': 4}, 'media_mensual_medicion': 22.918539325842698}
# {'_id': {'estacion': 'Castellana', 'mes': 5}, 'media_mensual_medicion': 15.987837837837837}
# {'_id': {'estacion': 'Castellana', 'mes': 6}, 'media_mensual_medicion': 22.02370990237099}
# {'_id': {'estacion': 'Castellana', 'mes': 7}, 'media_mensual_medicion': 21.41430499325236}
# {'_id': {'estacion': 'Castellana', 'mes': 8}, 'media_mensual_medicion': 18.5822102425876}
# {'_id': {'estacion': 'Castellana', 'mes': 9}, 'media_mensual_medicion': 33.107541899441344}
# {'_id': {'estacion': 'Castellana', 'mes': 10}, 'media_mensual_medicion': 29.85326086956522}
# {'_id': {'estacion': 'Castellana', 'mes': 11}, 'media_mensual_medicion': 34.147838214783825}
# {'_id': {'estacion': 'Castellana', 'mes': 12}, 'media_mensual_medicion': 44.917344173441734}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 1}, 'media_mensual_medicion': 40.42740841248304}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 2}, 'media_mensual_medicion': 40.36060606060606}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 3}, 'media_mensual_medicion': 26.825439783491206}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 4}, 'media_mensual_medicion': 20.6459802538787}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 5}, 'media_mensual_medicion': 17.654520917678813}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 6}, 'media_mensual_medicion': 21.904895104895104}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 7}, 'media_mensual_medicion': 19.557065217391305}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 8}, 'media_mensual_medicion': 16.844173441734416}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 9}, 'media_mensual_medicion': 32.38330975954738}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 10}, 'media_mensual_medicion': 31.752717391304348}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 11}, 'media_mensual_medicion': 32.909985935302394}
# {'_id': {'estacion': 'Cuatro Caminos', 'mes': 12}, 'media_mensual_medicion': 50.1866485013624}
# {'_id': {'estacion': 'El Pardo', 'mes': 1}, 'media_mensual_medicion': 16.536585365853657}
# {'_id': {'estacion': 'El Pardo', 'mes': 2}, 'media_mensual_medicion': 19.64724409448819}
# {'_id': {'estacion': 'El Pardo', 'mes': 3}, 'media_mensual_medicion': 14.008241758241759}
# {'_id': {'estacion': 'El Pardo', 'mes': 4}, 'media_mensual_medicion': 9.790794979079498}
# {'_id': {'estacion': 'El Pardo', 'mes': 5}, 'media_mensual_medicion': 7.924242424242424}
# {'_id': {'estacion': 'El Pardo', 'mes': 6}, 'media_mensual_medicion': 11.727653631284916}
# {'_id': {'estacion': 'El Pardo', 'mes': 7}, 'media_mensual_medicion': 10.08918918918919}
# {'_id': {'estacion': 'El Pardo', 'mes': 8}, 'media_mensual_medicion': 10.084010840108402}
# {'_id': {'estacion': 'El Pardo', 'mes': 9}, 'media_mensual_medicion': 13.405329593267883}
# {'_id': {'estacion': 'El Pardo', 'mes': 10}, 'media_mensual_medicion': 13.10945945945946}
# {'_id': {'estacion': 'El Pardo', 'mes': 11}, 'media_mensual_medicion': 12.242296918767506}
# {'_id': {'estacion': 'El Pardo', 'mes': 12}, 'media_mensual_medicion': 19.691576086956523}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 1}, 'media_mensual_medicion': 37.5840108401084}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 2}, 'media_mensual_medicion': 41.86342943854325}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 3}, 'media_mensual_medicion': 30.45047489823609}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 4}, 'media_mensual_medicion': 24.832167832167833}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 5}, 'media_mensual_medicion': 18.001351351351353}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 6}, 'media_mensual_medicion': 22.113286713286712}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 7}, 'media_mensual_medicion': 21.709066305818673}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 8}, 'media_mensual_medicion': 20.253044654939107}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 9}, 'media_mensual_medicion': 34.045197740113}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 10}, 'media_mensual_medicion': 31.466124661246614}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 11}, 'media_mensual_medicion': 33.76836158192091}
# {'_id': {'estacion': 'Ensanche de Vallecas', 'mes': 12}, 'media_mensual_medicion': 44.10176390773406}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 1}, 'media_mensual_medicion': 39.74219810040706}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 2}, 'media_mensual_medicion': 41.0990990990991}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 3}, 'media_mensual_medicion': 32.62655601659751}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 4}, 'media_mensual_medicion': 27.256661991584853}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 5}, 'media_mensual_medicion': 20.139001349527664}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 6}, 'media_mensual_medicion': 25.750700280112046}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 7}, 'media_mensual_medicion': 27.006765899864682}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 8}, 'media_mensual_medicion': 22.535859269282813}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 9}, 'media_mensual_medicion': 35.65119549929676}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 10}, 'media_mensual_medicion': 37.06216216216216}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 11}, 'media_mensual_medicion': 38.52683615819209}
# {'_id': {'estacion': 'Escuelas Aguirre', 'mes': 12}, 'media_mensual_medicion': 45.24086603518268}
# {'_id': {'estacion': 'Farolillo', 'mes': 1}, 'media_mensual_medicion': 33.486486486486484}
# {'_id': {'estacion': 'Farolillo', 'mes': 2}, 'media_mensual_medicion': 39.231231231231234}
# {'_id': {'estacion': 'Farolillo', 'mes': 3}, 'media_mensual_medicion': 25.55692729766804}
# {'_id': {'estacion': 'Farolillo', 'mes': 4}, 'media_mensual_medicion': 20.61624649859944}
# {'_id': {'estacion': 'Farolillo', 'mes': 5}, 'media_mensual_medicion': 15.813858695652174}
# {'_id': {'estacion': 'Farolillo', 'mes': 6}, 'media_mensual_medicion': 20.378809869375907}
# {'_id': {'estacion': 'Farolillo', 'mes': 7}, 'media_mensual_medicion': 18.820027063599458}
# {'_id': {'estacion': 'Farolillo', 'mes': 8}, 'media_mensual_medicion': 18.520325203252032}
# {'_id': {'estacion': 'Farolillo', 'mes': 9}, 'media_mensual_medicion': 28.551966292134832}
# {'_id': {'estacion': 'Farolillo', 'mes': 10}, 'media_mensual_medicion': 30.374149659863946}
# {'_id': {'estacion': 'Farolillo', 'mes': 11}, 'media_mensual_medicion': 29.191011235955056}
# {'_id': {'estacion': 'Farolillo', 'mes': 12}, 'media_mensual_medicion': 44.42162162162162}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 1}, 'media_mensual_medicion': 25.067842605156038}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 2}, 'media_mensual_medicion': 29.316733067729082}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 3}, 'media_mensual_medicion': 22.516574585635357}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 4}, 'media_mensual_medicion': 17.98186889818689}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 5}, 'media_mensual_medicion': 11.162381596752368}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 6}, 'media_mensual_medicion': 14.665185185185186}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 7}, 'media_mensual_medicion': 16.29810298102981}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 8}, 'media_mensual_medicion': 15.739837398373984}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 9}, 'media_mensual_medicion': 21.783216783216783}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 10}, 'media_mensual_medicion': 24.257759784075574}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 11}, 'media_mensual_medicion': 28.849162011173185}
# {'_id': {'estacion': 'Juan Carlos I', 'mes': 12}, 'media_mensual_medicion': 36.19267299864315}
# {'_id': {'estacion': 'Moratalaz', 'mes': 1}, 'media_mensual_medicion': 33.796221322537114}
# {'_id': {'estacion': 'Moratalaz', 'mes': 2}, 'media_mensual_medicion': 37.23592085235921}
# {'_id': {'estacion': 'Moratalaz', 'mes': 3}, 'media_mensual_medicion': 28.868027210884353}
# {'_id': {'estacion': 'Moratalaz', 'mes': 4}, 'media_mensual_medicion': 22.345454545454544}
# {'_id': {'estacion': 'Moratalaz', 'mes': 5}, 'media_mensual_medicion': 16.65764546684709}
# {'_id': {'estacion': 'Moratalaz', 'mes': 6}, 'media_mensual_medicion': 22.462833099579242}
# {'_id': {'estacion': 'Moratalaz', 'mes': 7}, 'media_mensual_medicion': 22.04054054054054}
# {'_id': {'estacion': 'Moratalaz', 'mes': 8}, 'media_mensual_medicion': 20.24076607387141}
# {'_id': {'estacion': 'Moratalaz', 'mes': 9}, 'media_mensual_medicion': 30.823943661971832}
# {'_id': {'estacion': 'Moratalaz', 'mes': 10}, 'media_mensual_medicion': 31.975675675675674}
# {'_id': {'estacion': 'Moratalaz', 'mes': 11}, 'media_mensual_medicion': 36.50348675034868}
# {'_id': {'estacion': 'Moratalaz', 'mes': 12}, 'media_mensual_medicion': 47.72764227642276}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 1}, 'media_mensual_medicion': 36.0148849797023}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 2}, 'media_mensual_medicion': 42.17522658610272}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 3}, 'media_mensual_medicion': 30.444141689373296}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 4}, 'media_mensual_medicion': 24.824267782426777}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 5}, 'media_mensual_medicion': 14.175271739130435}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 6}, 'media_mensual_medicion': 20.7703081232493}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 7}, 'media_mensual_medicion': 20.786197564276048}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 8}, 'media_mensual_medicion': 19.706293706293707}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 9}, 'media_mensual_medicion': 30.831697054698456}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 10}, 'media_mensual_medicion': 30.891304347826086}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 11}, 'media_mensual_medicion': 28.820224719101123}
# {'_id': {'estacion': 'Méndez Álvaro', 'mes': 12}, 'media_mensual_medicion': 37.868741542625166}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 1}, 'media_mensual_medicion': 26.554952510176392}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 2}, 'media_mensual_medicion': 32.83661119515885}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 3}, 'media_mensual_medicion': 21.9159891598916}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 4}, 'media_mensual_medicion': 16.198473282442748}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 5}, 'media_mensual_medicion': 12.732857142857142}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 6}, 'media_mensual_medicion': 15.125884016973126}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 7}, 'media_mensual_medicion': 13.01657458563536}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 8}, 'media_mensual_medicion': 11.521379310344827}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 9}, 'media_mensual_medicion': 19.007022471910112}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 10}, 'media_mensual_medicion': 21.265223274695533}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 11}, 'media_mensual_medicion': 23.746853146853148}
# {'_id': {'estacion': 'Parque del Retiro', 'mes': 12}, 'media_mensual_medicion': 29.850948509485097}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 1}, 'media_mensual_medicion': 36.22868741542625}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 2}, 'media_mensual_medicion': 36.51359516616314}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 3}, 'media_mensual_medicion': 34.69376693766937}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 4}, 'media_mensual_medicion': 24.786312849162012}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 5}, 'media_mensual_medicion': 17.85326086956522}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 6}, 'media_mensual_medicion': 23.674188998589564}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 7}, 'media_mensual_medicion': 24.533333333333335}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 8}, 'media_mensual_medicion': 20.005398110661268}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 9}, 'media_mensual_medicion': 31.166201117318437}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 10}, 'media_mensual_medicion': 34.174560216508794}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 11}, 'media_mensual_medicion': 36.70868347338936}
# {'_id': {'estacion': 'Plaza Castilla', 'mes': 12}, 'media_mensual_medicion': 44.96891891891892}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 1}, 'media_mensual_medicion': 43.287465940054496}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 2}, 'media_mensual_medicion': 50.678899082568805}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 3}, 'media_mensual_medicion': 31.872282608695652}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 4}, 'media_mensual_medicion': 29.705307262569832}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 5}, 'media_mensual_medicion': 28.431848852901485}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 6}, 'media_mensual_medicion': 35.85474860335196}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 7}, 'media_mensual_medicion': 31.319783197831978}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 8}, 'media_mensual_medicion': 27.033738191632928}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 9}, 'media_mensual_medicion': 39.419127988748244}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 10}, 'media_mensual_medicion': 38.64824797843666}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 11}, 'media_mensual_medicion': 34.340306834030685}
# {'_id': {'estacion': 'Plaza Elíptica', 'mes': 12}, 'media_mensual_medicion': 43.91474966170501}
# {'_id': {'estacion': 'Plaza de España', 'mes': 1}, 'media_mensual_medicion': 32.57608695652174}
# {'_id': {'estacion': 'Plaza de España', 'mes': 2}, 'media_mensual_medicion': 40.961832061068705}
# {'_id': {'estacion': 'Plaza de España', 'mes': 3}, 'media_mensual_medicion': 27.807639836289223}
# {'_id': {'estacion': 'Plaza de España', 'mes': 4}, 'media_mensual_medicion': 23.606993006993008}
# {'_id': {'estacion': 'Plaza de España', 'mes': 5}, 'media_mensual_medicion': 16.633152173913043}
# {'_id': {'estacion': 'Plaza de España', 'mes': 6}, 'media_mensual_medicion': 22.269662921348313}
# {'_id': {'estacion': 'Plaza de España', 'mes': 7}, 'media_mensual_medicion': 22.68825910931174}
# {'_id': {'estacion': 'Plaza de España', 'mes': 8}, 'media_mensual_medicion': 21.272972972972973}
# {'_id': {'estacion': 'Plaza de España', 'mes': 9}, 'media_mensual_medicion': 32.25983146067416}
# {'_id': {'estacion': 'Plaza de España', 'mes': 10}, 'media_mensual_medicion': 32.732700135685214}
# {'_id': {'estacion': 'Plaza de España', 'mes': 11}, 'media_mensual_medicion': 28.83916083916084}
# {'_id': {'estacion': 'Plaza de España', 'mes': 12}, 'media_mensual_medicion': 37.076190476190476}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 1}, 'media_mensual_medicion': 40.55817378497791}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 2}, 'media_mensual_medicion': 43.80809595202399}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 3}, 'media_mensual_medicion': 34.28528528528528}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 4}, 'media_mensual_medicion': 35.104046242774565}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 5}, 'media_mensual_medicion': 22.94808743169399}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 6}, 'media_mensual_medicion': 22.47316384180791}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 7}, 'media_mensual_medicion': 20.899592944369065}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 8}, 'media_mensual_medicion': 22.897018970189702}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 9}, 'media_mensual_medicion': 31.728643216080403}
# {'_id': {'estacion': 'Plaza del Carmen', 'mes': 12}, 'media_mensual_medicion': 38.58774373259053}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 1}, 'media_mensual_medicion': 40.56}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 3}, 'media_mensual_medicion': 25.851657940663177}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 4}, 'media_mensual_medicion': 24.666666666666668}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 5}, 'media_mensual_medicion': 19.066305818673882}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 6}, 'media_mensual_medicion': 26.087988826815643}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 7}, 'media_mensual_medicion': 22.974324324324325}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 8}, 'media_mensual_medicion': 20.10135135135135}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 9}, 'media_mensual_medicion': 35.94249649368864}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 10}, 'media_mensual_medicion': 35.442645074224025}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 11}, 'media_mensual_medicion': 35.044880785413746}
# {'_id': {'estacion': 'Ramón y Cajal', 'mes': 12}, 'media_mensual_medicion': 46.96612466124661}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 1}, 'media_mensual_medicion': 31.4027027027027}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 2}, 'media_mensual_medicion': 33.58346094946401}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 3}, 'media_mensual_medicion': 22.933694181326118}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 4}, 'media_mensual_medicion': 17.973426573426572}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 5}, 'media_mensual_medicion': 11.638211382113822}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 6}, 'media_mensual_medicion': 15.766433566433566}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 7}, 'media_mensual_medicion': 15.963513513513513}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 8}, 'media_mensual_medicion': 14.20782726045884}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 9}, 'media_mensual_medicion': 25.423988842398884}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 10}, 'media_mensual_medicion': 27.26265389876881}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 11}, 'media_mensual_medicion': 30.83960948396095}
# {'_id': {'estacion': 'Sanchinarro', 'mes': 12}, 'media_mensual_medicion': 42.155313351498634}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 1}, 'media_mensual_medicion': 27.425271739130434}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 2}, 'media_mensual_medicion': 34.18604651162791}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 3}, 'media_mensual_medicion': 20.674355495251017}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 4}, 'media_mensual_medicion': 15.261173184357542}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 5}, 'media_mensual_medicion': 9.997300944669366}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 6}, 'media_mensual_medicion': 12.501587301587302}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 7}, 'media_mensual_medicion': 15.065749235474007}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 8}, 'media_mensual_medicion': 13.895805142083898}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 9}, 'media_mensual_medicion': 20.45505617977528}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 10}, 'media_mensual_medicion': 20.813765182186234}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 11}, 'media_mensual_medicion': 23.350354609929077}
# {'_id': {'estacion': 'Tres Olivos', 'mes': 12}, 'media_mensual_medicion': 36.596888260254595}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 1}, 'media_mensual_medicion': 39.67530695770805}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 2}, 'media_mensual_medicion': 47.62537764350453}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 3}, 'media_mensual_medicion': 33.01219512195122}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 4}, 'media_mensual_medicion': 24.974789915966387}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 5}, 'media_mensual_medicion': 18.05570652173913}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 6}, 'media_mensual_medicion': 23.71107994389902}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 7}, 'media_mensual_medicion': 24.173677069199456}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 8}, 'media_mensual_medicion': 22.76923076923077}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 9}, 'media_mensual_medicion': 27.065573770491802}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 10}, 'media_mensual_medicion': 28.595108695652176}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 11}, 'media_mensual_medicion': 28.14365411436541}
# {'_id': {'estacion': 'Urb. Embajada', 'mes': 12}, 'media_mensual_medicion': 30.46502057613169}
# {'_id': {'estacion': 'Vallecas', 'mes': 1}, 'media_mensual_medicion': 34.949864498644985}
# {'_id': {'estacion': 'Vallecas', 'mes': 2}, 'media_mensual_medicion': 36.82078313253012}
# {'_id': {'estacion': 'Vallecas', 'mes': 3}, 'media_mensual_medicion': 29.606756756756756}
# {'_id': {'estacion': 'Vallecas', 'mes': 4}, 'media_mensual_medicion': 23.6}
# {'_id': {'estacion': 'Vallecas', 'mes': 5}, 'media_mensual_medicion': 17.935047361299052}
# {'_id': {'estacion': 'Vallecas', 'mes': 6}, 'media_mensual_medicion': 23.74125874125874}
# {'_id': {'estacion': 'Vallecas', 'mes': 7}, 'media_mensual_medicion': 22.525815217391305}
# {'_id': {'estacion': 'Vallecas', 'mes': 8}, 'media_mensual_medicion': 20.212162162162162}
# {'_id': {'estacion': 'Vallecas', 'mes': 9}, 'media_mensual_medicion': 34.088235294117645}
# {'_id': {'estacion': 'Vallecas', 'mes': 10}, 'media_mensual_medicion': 35.19864864864865}
# {'_id': {'estacion': 'Vallecas', 'mes': 11}, 'media_mensual_medicion': 38.719054242002784}
# {'_id': {'estacion': 'Vallecas', 'mes': 12}, 'media_mensual_medicion': 47.794316644113664}
# {'_id': {'estacion': 'Villaverde', 'mes': 1}, 'media_mensual_medicion': 48.30393487109905}
# {'_id': {'estacion': 'Villaverde', 'mes': 2}, 'media_mensual_medicion': 49.05343511450382}
# {'_id': {'estacion': 'Villaverde', 'mes': 3}, 'media_mensual_medicion': 35.74898236092266}
# {'_id': {'estacion': 'Villaverde', 'mes': 4}, 'media_mensual_medicion': 30.475920679886684}
# {'_id': {'estacion': 'Villaverde', 'mes': 5}, 'media_mensual_medicion': 20.183783783783785}
# {'_id': {'estacion': 'Villaverde', 'mes': 6}, 'media_mensual_medicion': 27.97752808988764}
# {'_id': {'estacion': 'Villaverde', 'mes': 7}, 'media_mensual_medicion': 30.42297297297297}
# {'_id': {'estacion': 'Villaverde', 'mes': 8}, 'media_mensual_medicion': 26.697297297297297}
# {'_id': {'estacion': 'Villaverde', 'mes': 9}, 'media_mensual_medicion': 39.4747191011236}
# {'_id': {'estacion': 'Villaverde', 'mes': 10}, 'media_mensual_medicion': 43.1}
# {'_id': {'estacion': 'Villaverde', 'mes': 11}, 'media_mensual_medicion': 37.7179125528914}
# {'_id': {'estacion': 'Villaverde', 'mes': 12}, 'media_mensual_medicion': 49.85576923076923}

# %% [markdown]
# En la consulta anterior, realizar un match por contaminante, como en este caso donde se filtra por la magnitud "no2", es importante porque nos permite reducir significativamente el conjunto de datos sobre los que estamos operando. Al filtrar por una magnitud específica, eliminamos todas las mediciones que no corresponden a ese contaminante en particular. Esto no solo reduce la carga de trabajo para el sistema al procesar menos datos, sino que también mejora la eficiencia de las consultas al enfocarse solo en la información relevante para el análisis que estamos realizando, lo que puede acelerar significativamente el tiempo de ejecución de las consultas y las operaciones de agregación.
#
# Pese a que la práctica no lo pida, a continuación crearemos varios gráficos para poder visualizar los resultados obtenidos de una forma más visual. Esto ilustra el trabajo que realizaría un analista de datos, una vez obtenidos los datos que necesita desde la base de datos.

# %%
import matplotlib.pyplot as plt

# Creamos una lista de todas las estaciones
estaciones = sorted(list(set([item['_id']['estacion'] for item in result])))

# Para cada estación, creamos un plot
for estacion in estaciones:
    
    # Listamos los meses que ha medido la estación
    meses = [item['_id']['mes'] for item in result if item['_id']['estacion'] == estacion]
    
    # Extraer las month_station_average asociadas a la estacion
    month_station_average = [item['media_mensual_medicion'] for item in result if item['_id']['estacion'] == estacion]

    # Crear el gráfico de columnas
    plt.figure(figsize=(10, 6))
    plt.bar(meses, month_station_average, color='skyblue')

    # Añadir etiquetas y título
    plt.xlabel('Meses del 2023')
    plt.ylabel('Promedio de contaminante')
    plt.title(f'Promedio de contaminante NO2 por mes del 2023 medido en la estación {estacion}')

    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# A partir de estos resultados, sería posible abarcar el objetivo de determinar si existe alguna correlación entre los niveles de NO2 y las épocas del año. Por ejemplo, vemos que en los meses de invierno la medición aumenta. Esta tendencia se puede visualizar en todas las estaciones. El aumento en las mediciones de NO2 durante los meses de invierno podría atribuirse a una combinación de factores, que incluyen el aumento del uso de calefacción, las inversiones térmicas, la menor dispersión de contaminantes y el aumento del tráfico. Harían falta análisis adicionales sobre las posibles causas y el trabajo de expertos en la materia para confirmar estos tipos de hipótesis.

# %% [markdown]
# #### Consulta 2: Promedio de NO2 por día en una estación en el 2023

# %%
# Operación de agregación para calcular la media de la medición por días en la estación plaza elíptica
pipeline = [
    {
        "$match": {
            "metadata.magnitud": "no2",  # Filtrar por la magnitud 'no2'
            "metadata.estacion": "Plaza de España",
            "timestamp": {  # Filtrar por el año 2023
                "$gte": datetime.datetime(2023, 1, 1), 
                "$lt": datetime.datetime(2024, 1, 1)
            }  
        }
    },
    {
        "$project": {
            "estacion": "$metadata.estacion",
            "dia": {"$dayOfYear": "$timestamp"},
            "medicion": "$medicion"
        }
    },
    {
        "$group": {
            "_id": {"estacion": "$estacion", "dia": "$dia"}, # Agrupar por estación y día
            "media_diaria_medicion": {"$avg": "$medicion"} # Calcular la media diaria de la medición
        }
    },
    {
        "$sort": {
            "_id.dia": 1  # Ordenar ascendentemente por dia
        }
    }
]

# Ejecutar la operación de agregación
result = list(air_quality_collection.aggregate(pipeline))

# Imprimir los resultados
for item in result:
    print(item)
# Out:
# {'_id': {'estacion': 'Plaza de España', 'dia': 1}, 'media_diaria_medicion': 35.416666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 2}, 'media_diaria_medicion': 33.958333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 3}, 'media_diaria_medicion': 35.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 4}, 'media_diaria_medicion': 42.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 5}, 'media_diaria_medicion': 44.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 6}, 'media_diaria_medicion': 39.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 7}, 'media_diaria_medicion': 38.708333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 8}, 'media_diaria_medicion': 11.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 9}, 'media_diaria_medicion': 28.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 10}, 'media_diaria_medicion': 38.416666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 11}, 'media_diaria_medicion': 26.38095238095238}
# {'_id': {'estacion': 'Plaza de España', 'dia': 12}, 'media_diaria_medicion': 41.208333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 13}, 'media_diaria_medicion': 43.583333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 14}, 'media_diaria_medicion': 40.541666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 15}, 'media_diaria_medicion': 14.083333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 16}, 'media_diaria_medicion': 10.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 17}, 'media_diaria_medicion': 6.916666666666667}
# {'_id': {'estacion': 'Plaza de España', 'dia': 18}, 'media_diaria_medicion': 16.083333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 19}, 'media_diaria_medicion': 13.083333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 20}, 'media_diaria_medicion': 33.041666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 21}, 'media_diaria_medicion': 27.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 22}, 'media_diaria_medicion': 23.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 23}, 'media_diaria_medicion': 40.82608695652174}
# {'_id': {'estacion': 'Plaza de España', 'dia': 24}, 'media_diaria_medicion': 27.958333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 25}, 'media_diaria_medicion': 32.95}
# {'_id': {'estacion': 'Plaza de España', 'dia': 26}, 'media_diaria_medicion': 49.291666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 27}, 'media_diaria_medicion': 39.916666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 28}, 'media_diaria_medicion': 30.833333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 29}, 'media_diaria_medicion': 27.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 30}, 'media_diaria_medicion': 46.875}
# {'_id': {'estacion': 'Plaza de España', 'dia': 31}, 'media_diaria_medicion': 69.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 32}, 'media_diaria_medicion': 52.666666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 33}, 'media_diaria_medicion': 66.66666666666667}
# {'_id': {'estacion': 'Plaza de España', 'dia': 34}, 'media_diaria_medicion': 73.58333333333333}
# {'_id': {'estacion': 'Plaza de España', 'dia': 35}, 'media_diaria_medicion': 71.875}
# {'_id': {'estacion': 'Plaza de España', 'dia': 36}, 'media_diaria_medicion': 50.041666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 37}, 'media_diaria_medicion': 37.916666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 38}, 'media_diaria_medicion': 37.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 39}, 'media_diaria_medicion': 28.454545454545453}
# {'_id': {'estacion': 'Plaza de España', 'dia': 40}, 'media_diaria_medicion': 41.916666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 41}, 'media_diaria_medicion': 39.875}
# {'_id': {'estacion': 'Plaza de España', 'dia': 42}, 'media_diaria_medicion': 25.875}
# {'_id': {'estacion': 'Plaza de España', 'dia': 43}, 'media_diaria_medicion': 22.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 44}, 'media_diaria_medicion': 35.958333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 45}, 'media_diaria_medicion': 31.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 46}, 'media_diaria_medicion': 41.791666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 47}, 'media_diaria_medicion': 47.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 48}, 'media_diaria_medicion': 51.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 49}, 'media_diaria_medicion': 45.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 50}, 'media_diaria_medicion': 41.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 51}, 'media_diaria_medicion': 37.08695652173913}
# {'_id': {'estacion': 'Plaza de España', 'dia': 52}, 'media_diaria_medicion': 44.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 53}, 'media_diaria_medicion': 40.78947368421053}
# {'_id': {'estacion': 'Plaza de España', 'dia': 54}, 'media_diaria_medicion': 15.933333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 55}, 'media_diaria_medicion': 41.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 56}, 'media_diaria_medicion': 38.833333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 57}, 'media_diaria_medicion': 28.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 58}, 'media_diaria_medicion': 16.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 59}, 'media_diaria_medicion': 30.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 60}, 'media_diaria_medicion': 41.69565217391305}
# {'_id': {'estacion': 'Plaza de España', 'dia': 61}, 'media_diaria_medicion': 46.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 62}, 'media_diaria_medicion': 44.458333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 63}, 'media_diaria_medicion': 40.416666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 64}, 'media_diaria_medicion': 47.708333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 65}, 'media_diaria_medicion': 20.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 66}, 'media_diaria_medicion': 15.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 67}, 'media_diaria_medicion': 16.833333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 68}, 'media_diaria_medicion': 18.72222222222222}
# {'_id': {'estacion': 'Plaza de España', 'dia': 69}, 'media_diaria_medicion': 17.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 70}, 'media_diaria_medicion': 13.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 71}, 'media_diaria_medicion': 24.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 72}, 'media_diaria_medicion': 20.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 73}, 'media_diaria_medicion': 17.208333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 74}, 'media_diaria_medicion': 45.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 75}, 'media_diaria_medicion': 50.875}
# {'_id': {'estacion': 'Plaza de España', 'dia': 76}, 'media_diaria_medicion': 14.458333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 77}, 'media_diaria_medicion': 13.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 78}, 'media_diaria_medicion': 31.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 79}, 'media_diaria_medicion': 26.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 80}, 'media_diaria_medicion': 42.916666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 81}, 'media_diaria_medicion': 32.23809523809524}
# {'_id': {'estacion': 'Plaza de España', 'dia': 82}, 'media_diaria_medicion': 26.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 83}, 'media_diaria_medicion': 14.416666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 84}, 'media_diaria_medicion': 14.291666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 85}, 'media_diaria_medicion': 12.217391304347826}
# {'_id': {'estacion': 'Plaza de España', 'dia': 86}, 'media_diaria_medicion': 29.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 87}, 'media_diaria_medicion': 49.416666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 88}, 'media_diaria_medicion': 43.791666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 89}, 'media_diaria_medicion': 15.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 90}, 'media_diaria_medicion': 11.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 91}, 'media_diaria_medicion': 8.416666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 92}, 'media_diaria_medicion': 12.958333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 93}, 'media_diaria_medicion': 24.291666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 94}, 'media_diaria_medicion': 20.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 95}, 'media_diaria_medicion': 31.55}
# {'_id': {'estacion': 'Plaza de España', 'dia': 96}, 'media_diaria_medicion': 33.458333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 97}, 'media_diaria_medicion': 22.416666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 98}, 'media_diaria_medicion': 31.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 99}, 'media_diaria_medicion': 31.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 100}, 'media_diaria_medicion': 35.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 101}, 'media_diaria_medicion': 26.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 102}, 'media_diaria_medicion': 12.958333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 103}, 'media_diaria_medicion': 14.041666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 104}, 'media_diaria_medicion': 10.458333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 105}, 'media_diaria_medicion': 11.958333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 106}, 'media_diaria_medicion': 10.833333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 107}, 'media_diaria_medicion': 20.083333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 108}, 'media_diaria_medicion': 21.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 109}, 'media_diaria_medicion': 24.91304347826087}
# {'_id': {'estacion': 'Plaza de España', 'dia': 110}, 'media_diaria_medicion': 40.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 111}, 'media_diaria_medicion': 31.541666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 112}, 'media_diaria_medicion': 10.916666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 113}, 'media_diaria_medicion': 16.208333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 114}, 'media_diaria_medicion': 20.791666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 115}, 'media_diaria_medicion': 22.333333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 116}, 'media_diaria_medicion': 34.583333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 117}, 'media_diaria_medicion': 47.541666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 118}, 'media_diaria_medicion': 41.291666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 119}, 'media_diaria_medicion': 27.333333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 120}, 'media_diaria_medicion': 11.458333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 121}, 'media_diaria_medicion': 10.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 122}, 'media_diaria_medicion': 25.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 123}, 'media_diaria_medicion': 32.27272727272727}
# {'_id': {'estacion': 'Plaza de España', 'dia': 124}, 'media_diaria_medicion': 9.583333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 125}, 'media_diaria_medicion': 25.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 126}, 'media_diaria_medicion': 28.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 127}, 'media_diaria_medicion': 13.583333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 128}, 'media_diaria_medicion': 25.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 129}, 'media_diaria_medicion': 18.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 130}, 'media_diaria_medicion': 11.416666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 131}, 'media_diaria_medicion': 9.458333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 132}, 'media_diaria_medicion': 9.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 133}, 'media_diaria_medicion': 8.083333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 134}, 'media_diaria_medicion': 11.416666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 135}, 'media_diaria_medicion': 12.791666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 136}, 'media_diaria_medicion': 10.791666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 137}, 'media_diaria_medicion': 7.6}
# {'_id': {'estacion': 'Plaza de España', 'dia': 138}, 'media_diaria_medicion': 9.458333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 139}, 'media_diaria_medicion': 9.291666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 140}, 'media_diaria_medicion': 11.166666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 141}, 'media_diaria_medicion': 9.666666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 142}, 'media_diaria_medicion': 18.416666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 143}, 'media_diaria_medicion': 13.041666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 144}, 'media_diaria_medicion': 16.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 145}, 'media_diaria_medicion': 26.791666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 146}, 'media_diaria_medicion': 19.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 147}, 'media_diaria_medicion': 15.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 148}, 'media_diaria_medicion': 16.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 149}, 'media_diaria_medicion': 29.208333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 150}, 'media_diaria_medicion': 29.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 151}, 'media_diaria_medicion': 23.363636363636363}
# {'_id': {'estacion': 'Plaza de España', 'dia': 152}, 'media_diaria_medicion': 23.333333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 153}, 'media_diaria_medicion': 20.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 154}, 'media_diaria_medicion': 17.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 155}, 'media_diaria_medicion': 16.541666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 156}, 'media_diaria_medicion': 25.416666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 157}, 'media_diaria_medicion': 22.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 158}, 'media_diaria_medicion': 26.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 159}, 'media_diaria_medicion': 20.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 160}, 'media_diaria_medicion': 16.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 161}, 'media_diaria_medicion': 13.416666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 162}, 'media_diaria_medicion': 12.958333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 163}, 'media_diaria_medicion': 16.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 164}, 'media_diaria_medicion': 19.541666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 165}, 'media_diaria_medicion': 18.476190476190474}
# {'_id': {'estacion': 'Plaza de España', 'dia': 166}, 'media_diaria_medicion': 25.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 167}, 'media_diaria_medicion': 31.541666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 168}, 'media_diaria_medicion': 33.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 169}, 'media_diaria_medicion': 12.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 170}, 'media_diaria_medicion': 21.52173913043478}
# {'_id': {'estacion': 'Plaza de España', 'dia': 171}, 'media_diaria_medicion': 12.708333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 172}, 'media_diaria_medicion': 25.083333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 173}, 'media_diaria_medicion': 28.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 174}, 'media_diaria_medicion': 25.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 175}, 'media_diaria_medicion': 25.291666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 176}, 'media_diaria_medicion': 31.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 177}, 'media_diaria_medicion': 29.958333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 178}, 'media_diaria_medicion': 30.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 179}, 'media_diaria_medicion': 23.9}
# {'_id': {'estacion': 'Plaza de España', 'dia': 180}, 'media_diaria_medicion': 30.166666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 181}, 'media_diaria_medicion': 9.583333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 182}, 'media_diaria_medicion': 13.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 183}, 'media_diaria_medicion': 15.583333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 184}, 'media_diaria_medicion': 16.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 185}, 'media_diaria_medicion': 24.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 186}, 'media_diaria_medicion': 23.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 187}, 'media_diaria_medicion': 19.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 188}, 'media_diaria_medicion': 19.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 189}, 'media_diaria_medicion': 14.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 190}, 'media_diaria_medicion': 26.208333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 191}, 'media_diaria_medicion': 43.041666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 192}, 'media_diaria_medicion': 38.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 193}, 'media_diaria_medicion': 28.304347826086957}
# {'_id': {'estacion': 'Plaza de España', 'dia': 194}, 'media_diaria_medicion': 26.166666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 195}, 'media_diaria_medicion': 28.791666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 196}, 'media_diaria_medicion': 11.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 197}, 'media_diaria_medicion': 16.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 198}, 'media_diaria_medicion': 46.666666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 199}, 'media_diaria_medicion': 36.291666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 200}, 'media_diaria_medicion': 18.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 201}, 'media_diaria_medicion': 25.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 202}, 'media_diaria_medicion': 16.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 203}, 'media_diaria_medicion': 15.208333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 204}, 'media_diaria_medicion': 27.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 205}, 'media_diaria_medicion': 15.083333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 206}, 'media_diaria_medicion': 11.863636363636363}
# {'_id': {'estacion': 'Plaza de España', 'dia': 207}, 'media_diaria_medicion': 21.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 208}, 'media_diaria_medicion': 24.875}
# {'_id': {'estacion': 'Plaza de España', 'dia': 209}, 'media_diaria_medicion': 20.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 210}, 'media_diaria_medicion': 23.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 211}, 'media_diaria_medicion': 18.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 212}, 'media_diaria_medicion': 16.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 213}, 'media_diaria_medicion': 21.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 214}, 'media_diaria_medicion': 24.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 215}, 'media_diaria_medicion': 11.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 216}, 'media_diaria_medicion': 6.208333333333333}
# {'_id': {'estacion': 'Plaza de España', 'dia': 217}, 'media_diaria_medicion': 14.583333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 218}, 'media_diaria_medicion': 16.833333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 219}, 'media_diaria_medicion': 19.291666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 220}, 'media_diaria_medicion': 27.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 221}, 'media_diaria_medicion': 39.04347826086956}
# {'_id': {'estacion': 'Plaza de España', 'dia': 222}, 'media_diaria_medicion': 20.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 223}, 'media_diaria_medicion': 36.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 224}, 'media_diaria_medicion': 29.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 225}, 'media_diaria_medicion': 19.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 226}, 'media_diaria_medicion': 21.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 227}, 'media_diaria_medicion': 18.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 228}, 'media_diaria_medicion': 24.791666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 229}, 'media_diaria_medicion': 30.208333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 230}, 'media_diaria_medicion': 16.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 231}, 'media_diaria_medicion': 18.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 232}, 'media_diaria_medicion': 29.333333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 233}, 'media_diaria_medicion': 35.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 234}, 'media_diaria_medicion': 26.791666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 235}, 'media_diaria_medicion': 19.19047619047619}
# {'_id': {'estacion': 'Plaza de España', 'dia': 236}, 'media_diaria_medicion': 23.541666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 237}, 'media_diaria_medicion': 19.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 238}, 'media_diaria_medicion': 13.208333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 239}, 'media_diaria_medicion': 4.416666666666667}
# {'_id': {'estacion': 'Plaza de España', 'dia': 240}, 'media_diaria_medicion': 13.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 241}, 'media_diaria_medicion': 14.166666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 242}, 'media_diaria_medicion': 14.041666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 243}, 'media_diaria_medicion': 31.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 244}, 'media_diaria_medicion': 36.958333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 245}, 'media_diaria_medicion': 32.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 246}, 'media_diaria_medicion': 12.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 247}, 'media_diaria_medicion': 23.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 248}, 'media_diaria_medicion': 30.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 249}, 'media_diaria_medicion': 39.391304347826086}
# {'_id': {'estacion': 'Plaza de España', 'dia': 250}, 'media_diaria_medicion': 35.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 251}, 'media_diaria_medicion': 36.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 252}, 'media_diaria_medicion': 22.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 253}, 'media_diaria_medicion': 21.166666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 254}, 'media_diaria_medicion': 26.791666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 255}, 'media_diaria_medicion': 36.208333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 256}, 'media_diaria_medicion': 26.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 257}, 'media_diaria_medicion': 30.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 258}, 'media_diaria_medicion': 20.958333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 259}, 'media_diaria_medicion': 25.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 260}, 'media_diaria_medicion': 20.166666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 261}, 'media_diaria_medicion': 26.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 262}, 'media_diaria_medicion': 31.083333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 263}, 'media_diaria_medicion': 25.36842105263158}
# {'_id': {'estacion': 'Plaza de España', 'dia': 264}, 'media_diaria_medicion': 14.708333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 265}, 'media_diaria_medicion': 18.565217391304348}
# {'_id': {'estacion': 'Plaza de España', 'dia': 266}, 'media_diaria_medicion': 35.208333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 267}, 'media_diaria_medicion': 41.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 268}, 'media_diaria_medicion': 52.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 269}, 'media_diaria_medicion': 56.416666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 270}, 'media_diaria_medicion': 45.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 271}, 'media_diaria_medicion': 47.833333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 272}, 'media_diaria_medicion': 50.291666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 273}, 'media_diaria_medicion': 46.17391304347826}
# {'_id': {'estacion': 'Plaza de España', 'dia': 274}, 'media_diaria_medicion': 45.916666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 275}, 'media_diaria_medicion': 49.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 276}, 'media_diaria_medicion': 56.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 277}, 'media_diaria_medicion': 49.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 278}, 'media_diaria_medicion': 58.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 279}, 'media_diaria_medicion': 54.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 280}, 'media_diaria_medicion': 53.208333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 281}, 'media_diaria_medicion': 50.916666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 282}, 'media_diaria_medicion': 61.666666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 283}, 'media_diaria_medicion': 59.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 284}, 'media_diaria_medicion': 58.333333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 285}, 'media_diaria_medicion': 46.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 286}, 'media_diaria_medicion': 42.416666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 287}, 'media_diaria_medicion': 29.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 288}, 'media_diaria_medicion': 21.083333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 289}, 'media_diaria_medicion': 18.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 290}, 'media_diaria_medicion': 23.73913043478261}
# {'_id': {'estacion': 'Plaza de España', 'dia': 291}, 'media_diaria_medicion': 9.130434782608695}
# {'_id': {'estacion': 'Plaza de España', 'dia': 292}, 'media_diaria_medicion': 20.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 293}, 'media_diaria_medicion': 11.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 294}, 'media_diaria_medicion': 14.791666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 295}, 'media_diaria_medicion': 21.416666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 296}, 'media_diaria_medicion': 20.333333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 297}, 'media_diaria_medicion': 13.833333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 298}, 'media_diaria_medicion': 12.166666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 299}, 'media_diaria_medicion': 11.541666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 300}, 'media_diaria_medicion': 17.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 301}, 'media_diaria_medicion': 11.208333333333334}
# {'_id': {'estacion': 'Plaza de España', 'dia': 302}, 'media_diaria_medicion': 12.791666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 303}, 'media_diaria_medicion': 19.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 304}, 'media_diaria_medicion': 41.73913043478261}
# {'_id': {'estacion': 'Plaza de España', 'dia': 305}, 'media_diaria_medicion': 22.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 306}, 'media_diaria_medicion': 8.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 307}, 'media_diaria_medicion': 12.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 308}, 'media_diaria_medicion': 8.166666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 309}, 'media_diaria_medicion': 9.875}
# {'_id': {'estacion': 'Plaza de España', 'dia': 310}, 'media_diaria_medicion': 27.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 311}, 'media_diaria_medicion': 28.208333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 312}, 'media_diaria_medicion': 33.291666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 313}, 'media_diaria_medicion': 13.666666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 314}, 'media_diaria_medicion': 19.083333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 315}, 'media_diaria_medicion': 7.458333333333333}
# {'_id': {'estacion': 'Plaza de España', 'dia': 316}, 'media_diaria_medicion': 13.166666666666666}
# {'_id': {'estacion': 'Plaza de España', 'dia': 317}, 'media_diaria_medicion': 24.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 318}, 'media_diaria_medicion': 39.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 319}, 'media_diaria_medicion': 38.18181818181818}
# {'_id': {'estacion': 'Plaza de España', 'dia': 320}, 'media_diaria_medicion': 48.869565217391305}
# {'_id': {'estacion': 'Plaza de España', 'dia': 321}, 'media_diaria_medicion': 53.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 322}, 'media_diaria_medicion': 35.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 323}, 'media_diaria_medicion': 39.208333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 324}, 'media_diaria_medicion': 45.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 325}, 'media_diaria_medicion': 29.666666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 326}, 'media_diaria_medicion': 19.583333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 327}, 'media_diaria_medicion': 44.291666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 328}, 'media_diaria_medicion': 57.958333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 329}, 'media_diaria_medicion': 54.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 330}, 'media_diaria_medicion': 43.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 331}, 'media_diaria_medicion': 32.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 332}, 'media_diaria_medicion': 19.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 333}, 'media_diaria_medicion': 20.40909090909091}
# {'_id': {'estacion': 'Plaza de España', 'dia': 334}, 'media_diaria_medicion': 17.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 335}, 'media_diaria_medicion': 24.916666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 336}, 'media_diaria_medicion': 28.708333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 337}, 'media_diaria_medicion': 33.833333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 338}, 'media_diaria_medicion': 29.125}
# {'_id': {'estacion': 'Plaza de España', 'dia': 339}, 'media_diaria_medicion': 36.91304347826087}
# {'_id': {'estacion': 'Plaza de España', 'dia': 340}, 'media_diaria_medicion': 39.541666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 341}, 'media_diaria_medicion': 41.708333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 342}, 'media_diaria_medicion': 19.458333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 343}, 'media_diaria_medicion': 19.041666666666668}
# {'_id': {'estacion': 'Plaza de España', 'dia': 344}, 'media_diaria_medicion': 19.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 345}, 'media_diaria_medicion': 30.75}
# {'_id': {'estacion': 'Plaza de España', 'dia': 346}, 'media_diaria_medicion': 39.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 347}, 'media_diaria_medicion': 25.2}
# {'_id': {'estacion': 'Plaza de España', 'dia': 348}, 'media_diaria_medicion': 39.625}
# {'_id': {'estacion': 'Plaza de España', 'dia': 349}, 'media_diaria_medicion': 38.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 350}, 'media_diaria_medicion': 42.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 351}, 'media_diaria_medicion': 40.0}
# {'_id': {'estacion': 'Plaza de España', 'dia': 352}, 'media_diaria_medicion': 49.21739130434783}
# {'_id': {'estacion': 'Plaza de España', 'dia': 353}, 'media_diaria_medicion': 50.458333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 354}, 'media_diaria_medicion': 26.958333333333332}
# {'_id': {'estacion': 'Plaza de España', 'dia': 355}, 'media_diaria_medicion': 59.291666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 356}, 'media_diaria_medicion': 47.78260869565217}
# {'_id': {'estacion': 'Plaza de España', 'dia': 357}, 'media_diaria_medicion': 38.375}
# {'_id': {'estacion': 'Plaza de España', 'dia': 358}, 'media_diaria_medicion': 37.083333333333336}
# {'_id': {'estacion': 'Plaza de España', 'dia': 359}, 'media_diaria_medicion': 34.791666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 360}, 'media_diaria_medicion': 46.541666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 361}, 'media_diaria_medicion': 48.25}
# {'_id': {'estacion': 'Plaza de España', 'dia': 362}, 'media_diaria_medicion': 51.95454545454545}
# {'_id': {'estacion': 'Plaza de España', 'dia': 363}, 'media_diaria_medicion': 48.5}
# {'_id': {'estacion': 'Plaza de España', 'dia': 364}, 'media_diaria_medicion': 44.166666666666664}
# {'_id': {'estacion': 'Plaza de España', 'dia': 365}, 'media_diaria_medicion': 17.791666666666668}

# %% [markdown]
# Al igual que antes, vamos a ilustrar el resultado de una forma visual:

# %%
# Extraer días y mediciones
dias = [item['_id']['dia'] for item in result]
mediciones = [item['media_diaria_medicion'] for item in result]

# Crear el gráfico
plt.figure(figsize=(15, 6))
plt.bar(dias, mediciones, color='skyblue')
# plt.plot(dias, mediciones, marker='o', linestyle='-')

# Etiquetas y título
plt.xlabel('Día del año 2023')
plt.ylabel('Medición NO2')
plt.title('Medias Diarias de NO2 en Plaza de España durante el año 2023')

# Mostrar el gráfico
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# A continuación analizaremos las estadísticas de ejecución del pipeline de agregación:

# %%
# Operación de agregación para calcular la media de la medición por días en la estación plaza elíptica
pipeline = [
    {
        "$match": {
            "metadata.magnitud": "no2",  # Filtrar por la magnitud 'no2'
            "metadata.estacion": "Plaza de España",
            "timestamp": {  # Filtrar por el año 2023
                "$gte": datetime.datetime(2023, 1, 1), 
                "$lt": datetime.datetime(2024, 1, 1)
            }  
        }
    },
    {
        "$project": {
            "estacion": "$metadata.estacion",
            "dia": {"$dayOfYear": "$timestamp"},
            "medicion": "$medicion"
        }
    },
    {
        "$group": {
            "_id": {"estacion": "$estacion", "dia": "$dia"}, # Agrupar por estación y día
            "media_diaria_medicion": {"$avg": "$medicion"} # Calcular la media diaria de la medición
        }
    },
    {
        "$sort": {
            "_id.dia": 1  # Ordenar ascendentemente por dia
        }
    }
]

explain_output = db.command('aggregate', 'air_quality_collection', pipeline=pipeline, explain=True)

pprint.pprint(explain_output)
# Out:
# {'command': {'$db': 'practica_maialen',
#              '$readPreference': {'mode': 'primaryPreferred'},
#              'aggregate': 'air_quality_collection',
#              'explain': True,
#              'lsid': {'id': UUID('60677f96-1568-4975-8332-c7a1f9d92687')},
#              'pipeline': [{'$match': {'metadata.estacion': 'Plaza de España',
#                                       'metadata.magnitud': 'no2',
#                                       'timestamp': {'$gte': datetime.datetime(2023, 1, 1, 0, 0),
#                                                     '$lt': datetime.datetime(2024, 1, 1, 0, 0)}}},
#                           {'$project': {'dia': {'$dayOfYear': '$timestamp'},
#                                         'estacion': '$metadata.estacion',
#                                         'medicion': '$medicion'}},
#                           {'$group': {'_id': {'dia': '$dia',
#                                               'estacion': '$estacion'},
#                                       'media_diaria_medicion': {'$avg': '$medicion'}}},
#                           {'$sort': {'_id.dia': 1}}]},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'serverInfo': {'gitVersion': '6f7dae919422dcd7f4892c10ff20cdc721ad00e6',
#                 'host': '91531c1afff5',
#                 'port': 27017,
#                 'version': '5.0.9'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0},
#  'stages': [{'$cursor': {'queryPlanner': {'indexFilterSet': False,
#                                           'maxIndexedAndSolutionsReached': False,
#                                           'maxIndexedOrSolutionsReached': False,
#                                           'maxScansToExplodeReached': False,
#                                           'namespace': 'practica_maialen.air_quality_collection',
#                                           'parsedQuery': {'$and': [{'metadata.estacion': {'$eq': 'Plaza '
#                                                                                                  'de '
#                                                                                                  'España'}},
#                                                                    {'metadata.magnitud': {'$eq': 'no2'}},
#                                                                    {'timestamp': {'$lt': datetime.datetime(2024, 1, 1, 0, 0)}},
#                                                                    {'timestamp': {'$gte': datetime.datetime(2023, 1, 1, 0, 0)}}]},
#                                           'planCacheKey': '2C3929FA',
#                                           'queryHash': '326C275F',
#                                           'rejectedPlans': [],
#                                           'winningPlan': {'inputStage': {'direction': 'forward',
#                                                                          'filter': {'$and': [{'metadata.estacion': {'$eq': 'Plaza '
#                                                                                                                            'de '
#                                                                                                                            'España'}},
#                                                                                              {'metadata.magnitud': {'$eq': 'no2'}},
#                                                                                              {'timestamp': {'$lt': datetime.datetime(2024, 1, 1, 0, 0)}},
#                                                                                              {'timestamp': {'$gte': datetime.datetime(2023, 1, 1, 0, 0)}}]},
#                                                                          'stage': 'COLLSCAN'},
#                                                           'stage': 'PROJECTION_DEFAULT',
#                                                           'transformBy': {'_id': True,
#                                                                           'dia': {'$dayOfYear': {'date': '$timestamp'}},
#                                                                           'estacion': '$metadata.estacion',
#                                                                           'medicion': '$medicion'}}}}},
#             {'$group': {'_id': {'dia': '$dia', 'estacion': '$estacion'},
#                         'media_diaria_medicion': {'$avg': '$medicion'}}},
#             {'$sort': {'sortKey': {'_id.dia': 1}}}]}

# %% [markdown]
# Si analizamos el resultado, en concreto, la sección **Stages** proporciona información sobre cada etapa del pipeline de agregación. Vemos que la primera etapa utiliza un **\$cursor** para realizar un escaneo de la colección. Se realizan filtros basados en el campo `metadata.magnitud`, `metadata.estacion` y `timestamp`. El parámetro `winningPlan` describe el plan de ejecución elegido por el optimizador de consultas como el más eficiente. En este caso, se utilizó un `COLLSCAN`, que indica que se realizó un escaneo completo de la colección sin utilizar un índice.
#
# Para mejorar la consulta, crearemos un índice compuesto en los campos utilizados en las etapas de $match. En este caso, los campos relevantes son `metadata.magnitud`, `metadata.estacion` y `timestamp`. Este índice compuesto ayudará a mejorar el rendimiento de la consulta al permitir que MongoDB realice búsquedas eficientes y ordenamientos en función de estos campos.

# %%
# Crear un índice compuesto en metadata.magnitud y timestamp
db.air_quality_collection.create_index([("metadata.magnitud", 1), ("metadata.estacion", 1), ("timestamp", 1)])
# Out:
# 'metadata.magnitud_1_metadata.estacion_1_timestamp_1'

# %%
# Operación de agregación para calcular la media de la medición por días en la estación plaza elíptica
pipeline = [
    {
        "$match": {
            "metadata.magnitud": "no2",  # Filtrar por la magnitud 'no2'
            "metadata.estacion": "Plaza de España",
            "timestamp": {  # Filtrar por el año 2023
                "$gte": datetime.datetime(2023, 1, 1), 
                "$lt": datetime.datetime(2024, 1, 1)
            }  
        }
    },
    {
        "$project": {
            "estacion": "$metadata.estacion",
            "dia": {"$dayOfYear": "$timestamp"},
            "medicion": "$medicion"
        }
    },
    {
        "$group": {
            "_id": {"estacion": "$estacion", "dia": "$dia"}, # Agrupar por estación y día
            "media_diaria_medicion": {"$avg": "$medicion"} # Calcular la media diaria de la medición
        }
    },
    {
        "$sort": {
            "_id.dia": 1  # Ordenar ascendentemente por dia
        }
    }
]

explain_output = db.command('aggregate', 'air_quality_collection', pipeline=pipeline, explain=True)

pprint.pprint(explain_output)
# Out:
# {'command': {'$db': 'practica_maialen',
#              '$readPreference': {'mode': 'primaryPreferred'},
#              'aggregate': 'air_quality_collection',
#              'explain': True,
#              'lsid': {'id': UUID('60677f96-1568-4975-8332-c7a1f9d92687')},
#              'pipeline': [{'$match': {'metadata.estacion': 'Plaza de España',
#                                       'metadata.magnitud': 'no2',
#                                       'timestamp': {'$gte': datetime.datetime(2023, 1, 1, 0, 0),
#                                                     '$lt': datetime.datetime(2024, 1, 1, 0, 0)}}},
#                           {'$project': {'dia': {'$dayOfYear': '$timestamp'},
#                                         'estacion': '$metadata.estacion',
#                                         'medicion': '$medicion'}},
#                           {'$group': {'_id': {'dia': '$dia',
#                                               'estacion': '$estacion'},
#                                       'media_diaria_medicion': {'$avg': '$medicion'}}},
#                           {'$sort': {'_id.dia': 1}}]},
#  'explainVersion': '1',
#  'ok': 1.0,
#  'serverInfo': {'gitVersion': '6f7dae919422dcd7f4892c10ff20cdc721ad00e6',
#                 'host': '91531c1afff5',
#                 'port': 27017,
#                 'version': '5.0.9'},
#  'serverParameters': {'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#                       'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#                       'internalLookupStageIntermediateDocumentMaxSizeBytes': 104857600,
#                       'internalQueryFacetBufferSizeBytes': 104857600,
#                       'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#                       'internalQueryMaxAddToSetBytes': 104857600,
#                       'internalQueryMaxBlockingSortMemoryUsageBytes': 104857600,
#                       'internalQueryProhibitBlockingMergeOnMongoS': 0},
#  'stages': [{'$cursor': {'queryPlanner': {'indexFilterSet': False,
#                                           'maxIndexedAndSolutionsReached': False,
#                                           'maxIndexedOrSolutionsReached': False,
#                                           'maxScansToExplodeReached': False,
#                                           'namespace': 'practica_maialen.air_quality_collection',
#                                           'parsedQuery': {'$and': [{'metadata.estacion': {'$eq': 'Plaza '
#                                                                                                  'de '
#                                                                                                  'España'}},
#                                                                    {'metadata.magnitud': {'$eq': 'no2'}},
#                                                                    {'timestamp': {'$lt': datetime.datetime(2024, 1, 1, 0, 0)}},
#                                                                    {'timestamp': {'$gte': datetime.datetime(2023, 1, 1, 0, 0)}}]},
#                                           'planCacheKey': 'C249820C',
#                                           'queryHash': '326C275F',
#                                           'rejectedPlans': [],
#                                           'winningPlan': {'inputStage': {'inputStage': {'direction': 'forward',
#                                                                                         'indexBounds': {'metadata.estacion': ['["Plaza '
#                                                                                                                               'de '
#                                                                                                                               'España", '
#                                                                                                                               '"Plaza '
#                                                                                                                               'de '
#                                                                                                                               'España"]'],
#                                                                                                         'metadata.magnitud': ['["no2", '
#                                                                                                                               '"no2"]'],
#                                                                                                         'timestamp': ['[new '
#                                                                                                                       'Date(1672531200000), '
#                                                                                                                       'new '
#                                                                                                                       'Date(1704067200000))']},
#                                                                                         'indexName': 'metadata.magnitud_1_metadata.estacion_1_timestamp_1',
#                                                                                         'indexVersion': 2,
#                                                                                         'isMultiKey': False,
#                                                                                         'isPartial': False,
#                                                                                         'isSparse': False,
#                                                                                         'isUnique': False,
#                                                                                         'keyPattern': {'metadata.estacion': 1,
#                                                                                                        'metadata.magnitud': 1,
#                                                                                                        'timestamp': 1},
#                                                                                         'multiKeyPaths': {'metadata.estacion': [],
#                                                                                                           'metadata.magnitud': [],
#                                                                                                           'timestamp': []},
#                                                                                         'stage': 'IXSCAN'},
#                                                                          'stage': 'FETCH'},
#                                                           'stage': 'PROJECTION_DEFAULT',
#                                                           'transformBy': {'_id': True,
#                                                                           'dia': {'$dayOfYear': {'date': '$timestamp'}},
#                                                                           'estacion': '$metadata.estacion',
#                                                                           'medicion': '$medicion'}}}}},
#             {'$group': {'_id': {'dia': '$dia', 'estacion': '$estacion'},
#                         'media_diaria_medicion': {'$avg': '$medicion'}}},
#             {'$sort': {'sortKey': {'_id.dia': 1}}}]}

# %% [markdown]
# El resultado muestra que se está utilizando un índice en la etapa **\$cursor**, donde indica `'stage': 'IXSCAN'` lo cual es una mejora respecto a la ausencia de índices.
#
# Revisando las ejecuciones del modo en que hemos hecho, MongoDB nos permite optimizar las consultas para nuestro caso de uso mediante la creación de índices.

# %% [markdown]
# #### Consulta 3: Evolución del NO2 por hora durante una semana del 2023 en una estación

# %%
# Operación de agregación para extraer los datos or horas del 16 al 22 en la estación plaza elíptica
query = {
    'metadata.magnitud': 'no2',
    'metadata.estacion': 'Plaza de España',
    'timestamp': {'$gte': datetime.datetime(2023, 1, 16), '$lte': datetime.datetime(2023, 1, 23)}
}

projection = {'timestamp': 1, 'medicion': 1, '_id': 0}


# Ejecutar la operación de agregación
result = list(air_quality_collection.find(query, projection))

# Imprimir los resultados
for item in result:
    print(item)
# Out:
# {'timestamp': datetime.datetime(2023, 1, 16, 0, 0), 'medicion': 6.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 1, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 2, 0), 'medicion': 2.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 3, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 4, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 5, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 6, 0), 'medicion': 14.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 7, 0), 'medicion': 20.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 8, 0), 'medicion': 23.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 9, 0), 'medicion': 29.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 10, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 11, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 12, 0), 'medicion': 8.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 13, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 14, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 15, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 16, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 17, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 18, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 19, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 20, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 21, 0), 'medicion': 8.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 22, 0), 'medicion': 6.0}
# {'timestamp': datetime.datetime(2023, 1, 16, 23, 0), 'medicion': 3.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 0, 0), 'medicion': 2.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 1, 0), 'medicion': 1.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 2, 0), 'medicion': 1.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 3, 0), 'medicion': 2.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 4, 0), 'medicion': 1.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 5, 0), 'medicion': 1.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 6, 0), 'medicion': 3.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 7, 0), 'medicion': 8.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 8, 0), 'medicion': 12.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 9, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 10, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 11, 0), 'medicion': 8.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 12, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 13, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 14, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 15, 0), 'medicion': 8.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 16, 0), 'medicion': 9.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 17, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 18, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 19, 0), 'medicion': 13.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 20, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 21, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 22, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 17, 23, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 0, 0), 'medicion': 3.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 1, 0), 'medicion': 3.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 2, 0), 'medicion': 3.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 3, 0), 'medicion': 2.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 4, 0), 'medicion': 1.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 5, 0), 'medicion': 2.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 6, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 7, 0), 'medicion': 14.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 8, 0), 'medicion': 22.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 9, 0), 'medicion': 22.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 10, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 11, 0), 'medicion': 14.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 12, 0), 'medicion': 24.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 13, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 14, 0), 'medicion': 16.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 15, 0), 'medicion': 16.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 16, 0), 'medicion': 15.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 17, 0), 'medicion': 22.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 18, 0), 'medicion': 24.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 19, 0), 'medicion': 35.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 20, 0), 'medicion': 35.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 21, 0), 'medicion': 34.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 22, 0), 'medicion': 25.0}
# {'timestamp': datetime.datetime(2023, 1, 18, 23, 0), 'medicion': 15.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 0, 0), 'medicion': 9.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 1, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 2, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 3, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 4, 0), 'medicion': 3.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 5, 0), 'medicion': 4.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 6, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 7, 0), 'medicion': 20.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 8, 0), 'medicion': 27.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 9, 0), 'medicion': 25.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 10, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 11, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 12, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 13, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 14, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 15, 0), 'medicion': 13.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 16, 0), 'medicion': 12.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 17, 0), 'medicion': 22.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 18, 0), 'medicion': 25.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 19, 0), 'medicion': 24.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 20, 0), 'medicion': 20.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 21, 0), 'medicion': 12.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 22, 0), 'medicion': 8.0}
# {'timestamp': datetime.datetime(2023, 1, 19, 23, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 0, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 1, 0), 'medicion': 9.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 2, 0), 'medicion': 4.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 3, 0), 'medicion': 5.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 4, 0), 'medicion': 15.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 5, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 6, 0), 'medicion': 27.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 7, 0), 'medicion': 33.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 8, 0), 'medicion': 57.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 9, 0), 'medicion': 60.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 10, 0), 'medicion': 66.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 11, 0), 'medicion': 57.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 12, 0), 'medicion': 36.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 13, 0), 'medicion': 16.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 14, 0), 'medicion': 13.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 15, 0), 'medicion': 12.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 16, 0), 'medicion': 16.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 17, 0), 'medicion': 21.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 18, 0), 'medicion': 38.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 19, 0), 'medicion': 46.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 20, 0), 'medicion': 47.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 21, 0), 'medicion': 51.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 22, 0), 'medicion': 69.0}
# {'timestamp': datetime.datetime(2023, 1, 20, 23, 0), 'medicion': 73.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 0, 0), 'medicion': 61.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 1, 0), 'medicion': 54.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 2, 0), 'medicion': 56.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 3, 0), 'medicion': 39.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 4, 0), 'medicion': 28.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 5, 0), 'medicion': 27.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 6, 0), 'medicion': 30.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 7, 0), 'medicion': 30.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 8, 0), 'medicion': 25.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 9, 0), 'medicion': 24.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 10, 0), 'medicion': 40.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 11, 0), 'medicion': 32.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 12, 0), 'medicion': 22.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 13, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 14, 0), 'medicion': 14.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 15, 0), 'medicion': 14.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 16, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 17, 0), 'medicion': 15.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 18, 0), 'medicion': 21.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 19, 0), 'medicion': 28.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 20, 0), 'medicion': 25.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 21, 0), 'medicion': 25.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 22, 0), 'medicion': 16.0}
# {'timestamp': datetime.datetime(2023, 1, 21, 23, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 0, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 1, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 2, 0), 'medicion': 10.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 3, 0), 'medicion': 7.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 4, 0), 'medicion': 6.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 5, 0), 'medicion': 8.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 6, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 7, 0), 'medicion': 34.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 8, 0), 'medicion': 50.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 9, 0), 'medicion': 34.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 10, 0), 'medicion': 17.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 11, 0), 'medicion': 14.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 12, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 13, 0), 'medicion': 11.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 14, 0), 'medicion': 13.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 15, 0), 'medicion': 12.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 16, 0), 'medicion': 12.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 17, 0), 'medicion': 15.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 18, 0), 'medicion': 30.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 19, 0), 'medicion': 37.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 20, 0), 'medicion': 51.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 21, 0), 'medicion': 53.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 22, 0), 'medicion': 33.0}
# {'timestamp': datetime.datetime(2023, 1, 22, 23, 0), 'medicion': 61.0}

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates


# Extraer timestamps y mediciones
timestamps = [item['timestamp'] for item in result]
mediciones = [item['medicion'] for item in result]

# Crear el gráfico
plt.figure(figsize=(15, 6))
plt.plot(timestamps, mediciones, marker='o', linestyle='-')

# Formatear el eje x para mostrar las fechas
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M'))
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())  # Máximo de 12 etiquetas en el eje x

# Rotar los ticks del eje x para una mejor visualización
plt.xticks(rotation=45)

# Etiquetas y título
plt.xlabel('Tiempo')
plt.ylabel('Medición NO2')
plt.title('Mediciones de NO2 por horas durante la semana del 16 al 23 de Enero del 2023 en Plaza de España')

# Mostrar el gráfico
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# En este caso, los datos parecen mostrar una tendencia incipiente que de lunes a viernes hay dos picos de NO2. Necesitaríamos más análisis y el criterio de un experto en la materia para poder extraer conclusiones y confirmar las hipótesis a partir de los resultados.

# %% [markdown]
# ## Conclusiones
#
# ### ¿Qué te parece la base de datos seleccionada como data store?
# Después de evaluar las características y capacidades de las bases de datos de documentos, así como las particularidades de MongoDB y Elasticsearch, he decidido implementar el caso de uso utilizando MongoDB. Esta decisión se ha basado en la familiaridad con la plataforma, así como sus características de consistencia, su escalabilidad automática y su eficiente gestión de series temporales. La elección ha resultado ser acertada. La capacidad de MongoDB para manejar series temporales ha sido especialmente útil para nuestro caso de uso.
#
#
#
# ### ¿Qué te ha parecido el ejercicio?
# El ejercicio ha sido enriquecedor y considero que he aprendido mucho. Aunque estoy más familiarizada con el análisis de datos, este ejercicio me ha dado la oportunidad de pensar y actuar como ingeniera de datos. Al principio me ha costado mucho enfocarlo desde la ingeniería de datos, y no desde la analítica. Sin embargo, el enunciado y las preguntas planteadas han sido esclarecedoras y me han guiado para abordar el problema desde una perspectiva diferente
#
#
# ### ¿Qué has aprendido?
# Durante este ejercicio, he adquirido varios conocimientos importantes:
#
# - Características de diferentes sistemas de bases de datos y sus posibles casos de uso.
# - Selección del sistema de base de datos más adecuado para un caso de uso específico.
# - Diseño del modelo de datos basado en el caso de uso y las consultas requeridas.
# - Implementación de la solución en MongoDB, incluyendo:
#     - Optimización de consultas
#     - Manejo de series temporales. Quiero destacar esto último, ya que me ha ayudado mucho a entender cómo funcionan las series temporales.
#
#
# ### ¿Qué has echado de menos?
# En mi caso, hubiera sido beneficioso contar con más tiempo para desarrollar y afinar la parte de indexación. Por otra parte, también me habría gustado disponer de tiempo adicional para implementar la solución en Elasticsearch y comparar los procesos entre ambos sistemas.
#
#
# ### ¿Cómo mejorarías la práctica?
# Considero que sería beneficioso incorporar ejemplos de prácticas realizadas en años anteriores, utilizando conjuntos de datos diferentes. Esto nos proporcionaría una referencia adicional y nos permitiría comprender mejor el enfoque.
#
# En cuanto al resto, considero que es una práctica muy acertada. No identifico áreas específicas que necesiten mejoras. El uso de Jupyter Notebook es especialmente adecuado, ya que proporciona una plataforma interactiva y versátil para la exploración y el análisis de datos.
#
#
#
# ### Futuras líneas
#
# **Otras aplicaciones a nuestro actual modelo**
#
# analizar los días de la semana y la fluctuación de los contaminantes (lunes a viernes), incluso dentro de un mismo día cómo fluctúan con las horas
#
# **Análisis espacial**
#
# Mi caso de uso secundario es análisis espacial. Para esto, tendré que realizar dos consultas a dos colecciones, no sólo una. Para esto mi modelo no está OK.
# 	*** Implementar referencias usando ObjectIDs.
# 	*** Implementar las geospacial
#
# **Incorporar nuevos datasets para buscar correlación**
#
# Existe alguna correlación entre la concentración de ciertos contaminantes y la salud pública, como tasas de enfermedades respiratorias o de hospitalización?
#
# **Automatización**
#
# Podríamos programar para que las consultas se realicen cada mes, ya que la fuente de datos también se actualiza de manera mensual, y de este modo, puedan seguir con dicho análisis mes tras mes.
#
# ### Ejemplo geoespacial
# **Caso de uso**: cantidad promedio de contaminantes medidos en las estaciones de Madrid el año 2023. La idea de este análisis inicial es obtener una visión global inicial de los datos basado en el **análisis espacial** de las estaciones.
#
# Comenzamos realizando el promedio anual de cada uno de los contaminantes en cada una de las estaciones. Hacemos un promedio y no la suma, ya que no todas las estaciones tienen registradas la misma cantidad de datos. Hay veces que han habido mediciones erróneas y se han descartado, por lo que la suma sería un cálculo inadecuado y desbalanceado.

# %%
import datetime

# Operación de agregación para calcular el promedio de la medición en el año 2023 por magnitud y estación
pipeline = [
    {
        "$match": {
            "timestamp": {
                "$gte": datetime.datetime(2023, 1, 1),  # A partir del 1 de enero de 2023
                "$lt": datetime.datetime(2024, 1, 1)    # Antes del 1 de enero de 2024
            }
        }
    },
    {
        "$group": {
            "_id": {
                "magnitud": "$metadata.magnitud",
                "estacion": "$metadata.estacion"
            },
            "promedio_medicion": {"$avg": "$medicion"}
        }
    },
    {
        "$sort": {
            "_id.magnitud": 1, # Ordenar ascendentemente por contaminante
            "promedio_medicion": -1  # Ordenar descendentemente según el resultado
        }
    }
]

# Ejecutar la operación de agregación
results = list(air_quality_collection.aggregate(pipeline))

# Imprimir los resultados
for doc in results:
    print(doc)
# Out:
# {'_id': {'magnitud': 'ben', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 0.43427661832331094}
# {'_id': {'magnitud': 'ben', 'estacion': 'Ramón y Cajal'}, 'promedio_medicion': 0.4340080410370165}
# {'_id': {'magnitud': 'ben', 'estacion': 'Farolillo'}, 'promedio_medicion': 0.38823981552651804}
# {'_id': {'magnitud': 'ben', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 0.34651518719095836}
# {'_id': {'magnitud': 'ben', 'estacion': 'Urb. Embajada'}, 'promedio_medicion': 0.3297972654408298}
# {'_id': {'magnitud': 'ben', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 0.3027566873028852}
# {'_id': {'magnitud': 'co', 'estacion': 'Plaza de España'}, 'promedio_medicion': 0.3645963451306963}
# {'_id': {'magnitud': 'co', 'estacion': 'Plaza del Carmen'}, 'promedio_medicion': 0.36155372405372405}
# {'_id': {'magnitud': 'co', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 0.3232041642567958}
# {'_id': {'magnitud': 'co', 'estacion': 'Plaza Elíptica'}, 'promedio_medicion': 0.31137517305029994}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 0.31403091557669444}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 0.2771856786011657}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Farolillo'}, 'promedio_medicion': 0.24229828850855747}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Urb. Embajada'}, 'promedio_medicion': 0.19208692571158617}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 0.1383811090225564}
# {'_id': {'magnitud': 'ebe', 'estacion': 'Ramón y Cajal'}, 'promedio_medicion': 0.10436213991769548}
# {'_id': {'magnitud': 'no', 'estacion': 'Villaverde'}, 'promedio_medicion': 23.162155910247513}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza Elíptica'}, 'promedio_medicion': 19.196430627518712}
# {'_id': {'magnitud': 'no', 'estacion': 'Ensanche de Vallecas'}, 'promedio_medicion': 13.829586071716822}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza del Carmen'}, 'promedio_medicion': 13.366809643543855}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza de España'}, 'promedio_medicion': 13.263759086188992}
# {'_id': {'magnitud': 'no', 'estacion': 'Urb. Embajada'}, 'promedio_medicion': 12.712414512576794}
# {'_id': {'magnitud': 'no', 'estacion': 'Barrio del Pilar'}, 'promedio_medicion': 12.260340632603405}
# {'_id': {'magnitud': 'no', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 11.913194043633846}
# {'_id': {'magnitud': 'no', 'estacion': 'Plaza Castilla'}, 'promedio_medicion': 11.777317213586644}
# {'_id': {'magnitud': 'no', 'estacion': 'Barajas Pueblo'}, 'promedio_medicion': 11.20449567723343}
# {'_id': {'magnitud': 'no', 'estacion': 'Méndez Álvaro'}, 'promedio_medicion': 10.781654343807764}
# {'_id': {'magnitud': 'no', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 10.270818915801614}
# {'_id': {'magnitud': 'no', 'estacion': 'Moratalaz'}, 'promedio_medicion': 9.7422775472568}
# {'_id': {'magnitud': 'no', 'estacion': 'Ramón y Cajal'}, 'promedio_medicion': 9.648969564623993}
# {'_id': {'magnitud': 'no', 'estacion': 'Farolillo'}, 'promedio_medicion': 9.388092485549134}
# {'_id': {'magnitud': 'no', 'estacion': 'Vallecas'}, 'promedio_medicion': 8.865846649040119}
# {'_id': {'magnitud': 'no', 'estacion': 'Sanchinarro'}, 'promedio_medicion': 7.926497695852534}
# {'_id': {'magnitud': 'no', 'estacion': 'Arturo Soria'}, 'promedio_medicion': 7.7700977573318}
# {'_id': {'magnitud': 'no', 'estacion': 'Tres Olivos'}, 'promedio_medicion': 6.84922604277443}
# {'_id': {'magnitud': 'no', 'estacion': 'Juan Carlos I'}, 'promedio_medicion': 6.37185988913787}
# {'_id': {'magnitud': 'no', 'estacion': 'Castellana'}, 'promedio_medicion': 6.269279393173198}
# {'_id': {'magnitud': 'no', 'estacion': 'Parque del Retiro'}, 'promedio_medicion': 5.882469886562975}
# {'_id': {'magnitud': 'no', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 4.399052478134111}
# {'_id': {'magnitud': 'no', 'estacion': 'El Pardo'}, 'promedio_medicion': 3.5214674227519964}
# {'_id': {'magnitud': 'no2', 'estacion': 'Villaverde'}, 'promedio_medicion': 36.470506592644}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza Elíptica'}, 'promedio_medicion': 36.07472654001151}
# {'_id': {'magnitud': 'no2', 'estacion': 'Barajas Pueblo'}, 'promedio_medicion': 33.514236311239195}
# {'_id': {'magnitud': 'no2', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 32.65167243367935}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza del Carmen'}, 'promedio_medicion': 30.982103239165802}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza Castilla'}, 'promedio_medicion': 30.41266551525619}
# {'_id': {'magnitud': 'no2', 'estacion': 'Vallecas'}, 'promedio_medicion': 30.386826071962293}
# {'_id': {'magnitud': 'no2', 'estacion': 'Ensanche de Vallecas'}, 'promedio_medicion': 29.909028017986856}
# {'_id': {'magnitud': 'no2', 'estacion': 'Ramón y Cajal'}, 'promedio_medicion': 29.578272144124472}
# {'_id': {'magnitud': 'no2', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 29.200623340644118}
# {'_id': {'magnitud': 'no2', 'estacion': 'Moratalaz'}, 'promedio_medicion': 29.169778699861688}
# {'_id': {'magnitud': 'no2', 'estacion': 'Urb. Embajada'}, 'promedio_medicion': 28.895676364900893}
# {'_id': {'magnitud': 'no2', 'estacion': 'Castellana'}, 'promedio_medicion': 28.771750373520284}
# {'_id': {'magnitud': 'no2', 'estacion': 'Barrio del Pilar'}, 'promedio_medicion': 28.154095701540957}
# {'_id': {'magnitud': 'no2', 'estacion': 'Plaza de España'}, 'promedio_medicion': 28.116303219106957}
# {'_id': {'magnitud': 'no2', 'estacion': 'Méndez Álvaro'}, 'promedio_medicion': 28.02888170055453}
# {'_id': {'magnitud': 'no2', 'estacion': 'Arturo Soria'}, 'promedio_medicion': 27.260839562967224}
# {'_id': {'magnitud': 'no2', 'estacion': 'Farolillo'}, 'promedio_medicion': 27.03179190751445}
# {'_id': {'magnitud': 'no2', 'estacion': 'Sanchinarro'}, 'promedio_medicion': 24.007142857142856}
# {'_id': {'magnitud': 'no2', 'estacion': 'Juan Carlos I'}, 'promedio_medicion': 21.825569052954357}
# {'_id': {'magnitud': 'no2', 'estacion': 'Tres Olivos'}, 'promedio_medicion': 20.811532553468037}
# {'_id': {'magnitud': 'no2', 'estacion': 'Parque del Retiro'}, 'promedio_medicion': 20.313530581218572}
# {'_id': {'magnitud': 'no2', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 16.0428814382896}
# {'_id': {'magnitud': 'no2', 'estacion': 'El Pardo'}, 'promedio_medicion': 13.129151718551094}
# {'_id': {'magnitud': 'nox', 'estacion': 'Villaverde'}, 'promedio_medicion': 71.99467962063382}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza Elíptica'}, 'promedio_medicion': 65.50719631548647}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza del Carmen'}, 'promedio_medicion': 51.490312084011244}
# {'_id': {'magnitud': 'nox', 'estacion': 'Ensanche de Vallecas'}, 'promedio_medicion': 51.11530035743111}
# {'_id': {'magnitud': 'nox', 'estacion': 'Barajas Pueblo'}, 'promedio_medicion': 50.705590778097985}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza Castilla'}, 'promedio_medicion': 48.4671272308578}
# {'_id': {'magnitud': 'nox', 'estacion': 'Plaza de España'}, 'promedio_medicion': 48.45298257759317}
# {'_id': {'magnitud': 'nox', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 48.4161476355248}
# {'_id': {'magnitud': 'nox', 'estacion': 'Urb. Embajada'}, 'promedio_medicion': 48.37498551060624}
# {'_id': {'magnitud': 'nox', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 47.46796721689946}
# {'_id': {'magnitud': 'nox', 'estacion': 'Barrio del Pilar'}, 'promedio_medicion': 46.96164986675936}
# {'_id': {'magnitud': 'nox', 'estacion': 'Méndez Álvaro'}, 'promedio_medicion': 44.56931608133087}
# {'_id': {'magnitud': 'nox', 'estacion': 'Ramón y Cajal'}, 'promedio_medicion': 44.38255766343661}
# {'_id': {'magnitud': 'nox', 'estacion': 'Moratalaz'}, 'promedio_medicion': 44.106039649608114}
# {'_id': {'magnitud': 'nox', 'estacion': 'Vallecas'}, 'promedio_medicion': 43.98678008966548}
# {'_id': {'magnitud': 'nox', 'estacion': 'Farolillo'}, 'promedio_medicion': 41.438150289017344}
# {'_id': {'magnitud': 'nox', 'estacion': 'Arturo Soria'}, 'promedio_medicion': 39.18435882691202}
# {'_id': {'magnitud': 'nox', 'estacion': 'Castellana'}, 'promedio_medicion': 38.39891966440639}
# {'_id': {'magnitud': 'nox', 'estacion': 'Sanchinarro'}, 'promedio_medicion': 36.16532258064516}
# {'_id': {'magnitud': 'nox', 'estacion': 'Juan Carlos I'}, 'promedio_medicion': 31.562920155678736}
# {'_id': {'magnitud': 'nox', 'estacion': 'Tres Olivos'}, 'promedio_medicion': 31.30745598487534}
# {'_id': {'magnitud': 'nox', 'estacion': 'Parque del Retiro'}, 'promedio_medicion': 29.305227458776752}
# {'_id': {'magnitud': 'nox', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 22.73080660835763}
# {'_id': {'magnitud': 'nox', 'estacion': 'El Pardo'}, 'promedio_medicion': 18.53292443004282}
# {'_id': {'magnitud': 'o3', 'estacion': 'Juan Carlos I'}, 'promedio_medicion': 61.71393869288606}
# {'_id': {'magnitud': 'o3', 'estacion': 'El Pardo'}, 'promedio_medicion': 59.74434520357267}
# {'_id': {'magnitud': 'o3', 'estacion': 'Tres Olivos'}, 'promedio_medicion': 58.30505935231071}
# {'_id': {'magnitud': 'o3', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 57.89876226062587}
# {'_id': {'magnitud': 'o3', 'estacion': 'Barrio del Pilar'}, 'promedio_medicion': 57.429780818740575}
# {'_id': {'magnitud': 'o3', 'estacion': 'Plaza del Carmen'}, 'promedio_medicion': 57.1436230248307}
# {'_id': {'magnitud': 'o3', 'estacion': 'Arturo Soria'}, 'promedio_medicion': 56.62648380776766}
# {'_id': {'magnitud': 'o3', 'estacion': 'Parque del Retiro'}, 'promedio_medicion': 56.21402517943287}
# {'_id': {'magnitud': 'o3', 'estacion': 'Farolillo'}, 'promedio_medicion': 54.63845704266511}
# {'_id': {'magnitud': 'o3', 'estacion': 'Ensanche de Vallecas'}, 'promedio_medicion': 53.37174893075945}
# {'_id': {'magnitud': 'o3', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 53.278897382441514}
# {'_id': {'magnitud': 'o3', 'estacion': 'Barajas Pueblo'}, 'promedio_medicion': 52.36834182491894}
# {'_id': {'magnitud': 'o3', 'estacion': 'Villaverde'}, 'promedio_medicion': 51.87254221605367}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Plaza Elíptica'}, 'promedio_medicion': 23.530004688232538}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Urb. Embajada'}, 'promedio_medicion': 23.51066336750324}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 20.601326970084973}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Farolillo'}, 'promedio_medicion': 19.9400214209211}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 18.98926738217452}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Plaza Castilla'}, 'promedio_medicion': 18.9144018583043}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Tres Olivos'}, 'promedio_medicion': 18.21059972105997}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Méndez Álvaro'}, 'promedio_medicion': 18.20837733192538}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Moratalaz'}, 'promedio_medicion': 17.87747353888633}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Castellana'}, 'promedio_medicion': 17.678597968788704}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Vallecas'}, 'promedio_medicion': 16.42842055855433}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 15.809450679267572}
# {'_id': {'magnitud': 'pm10', 'estacion': 'Sanchinarro'}, 'promedio_medicion': 15.493539750902107}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Plaza Elíptica'}, 'promedio_medicion': 12.361215834118756}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Castellana'}, 'promedio_medicion': 10.17970297029703}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 9.923202234116825}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 9.654101221640488}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Méndez Álvaro'}, 'promedio_medicion': 9.281747891283974}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Sanchinarro'}, 'promedio_medicion': 8.475942028985507}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Plaza Castilla'}, 'promedio_medicion': 8.16857076241548}
# {'_id': {'magnitud': 'pm2_5', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 7.6201974545022}
# {'_id': {'magnitud': 'so2', 'estacion': 'Plaza del Carmen'}, 'promedio_medicion': 3.6034916640452974}
# {'_id': {'magnitud': 'so2', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 2.8218889149285213}
# {'_id': {'magnitud': 'so2', 'estacion': 'Moratalaz'}, 'promedio_medicion': 1.9923604816781044}
# {'_id': {'magnitud': 'so2', 'estacion': 'Plaza de España'}, 'promedio_medicion': 1.5443773234200744}
# {'_id': {'magnitud': 'tol', 'estacion': 'Ramón y Cajal'}, 'promedio_medicion': 2.1989526478831687}
# {'_id': {'magnitud': 'tol', 'estacion': 'Escuelas Aguirre'}, 'promedio_medicion': 2.093275821318837}
# {'_id': {'magnitud': 'tol', 'estacion': 'Farolillo'}, 'promedio_medicion': 1.7603900297042492}
# {'_id': {'magnitud': 'tol', 'estacion': 'Cuatro Caminos'}, 'promedio_medicion': 1.752066800900154}
# {'_id': {'magnitud': 'tol', 'estacion': 'Casa de Campo'}, 'promedio_medicion': 1.312375600046833}
# {'_id': {'magnitud': 'tol', 'estacion': 'Urb. Embajada'}, 'promedio_medicion': 1.2048303967397818}

# %% [markdown]
# De este modo, podemos ver qué estaciones tienen qué cantidades de contaminantes.
#
# Basándose en esta consulta, posteriormente, un analista de datos podrá dibujar gráficos para poder presentar la información de una forma visual. Ejemplo de los gráficos que se pueden extraer a partir de esta consulta:

# %%
import matplotlib.pyplot as plt

# Creamos una lista de todos los contaminantes
contaminantes = list(set([item['_id']['magnitud'] for item in results]))

# Para cada contaminante, creamos un plot
for contaminante in contaminantes:
    
    # Listamos las estaciones que han medido el contaminante
    estaciones = [item['_id']['estacion'] for item in results if item['_id']['magnitud'] == contaminante]
    
    # Extraer las station_average asociadas al contaminante
    station_average = [item['promedio_medicion'] for item in results if item['_id']['magnitud'] == contaminante]

    # Crear el gráfico de columnas
    plt.figure(figsize=(15, 6))
    plt.bar(estaciones, station_average, color='skyblue')
    
    # Rotar las etiquetas de la eje x en un ángulo de 45 grados
    plt.xticks(rotation=45)

    # Añadir etiquetas y título
    plt.xlabel('Estación')
    plt.ylabel('Promedio de valor medido')
    plt.title(f'{contaminante.upper()}: Promedio por estación en 2023')

    # Mostrar el gráfico
    plt.show()

# %% [markdown]
# ## Bibliografía
#
#
# - Time Series - MongoDB - https://www.mongodb.com/docs/manual/core/timeseries-collections/
#
# - Time Series with MongoDB - Medium - https://medium.com/data-reply-it-datatech/time-series-with-mongodb-dd60f8d6acd6
#
# - Working with Time Series Data in MongoDB - Youtube - https://www.youtube.com/watch?v=c4A1dCQlKJQ
#
# - Geospatial Indexes - MongoDB - https://www.mongodb.com/docs/manual/core/indexes/index-types/index-geospatial/
#
# - DIRECTIVA 2008/50/CE DEL PARLAMENTO EUROPEO Y DEL CONSEJO de 21 de mayo de 2008 relativa a la calidad del aire ambiente y a una atmósfera más limpia en Europa - https://eur-lex.europa.eu/legal-content/ES/TXT/PDF/?uri=CELEX:32008L0050
